# %%
#Importación de librerías

import pandas as pd # libreria de python para manipulacion de datos
import sqlite3 # SQLite

# Los datos de entrada están disponibles en el directorio "../input/".

path = "/content/database.sqlite"
database = path

# Creamos la conexión con la BD y listaremos las tablas con las que contamos

conn = sqlite3.connect(database)
print ("Conexión exitosa")

# Listar las tablas con las que contamos
tables = pd.read_sql("""SELECT name
                        FROM sqlite_master
                        WHERE type='table';""", conn)

# Mostrar las tablas
print(tables)
# Out:
# Conexión exitosa
#                 name
# 0    sqlite_sequence
# 1  Player_Attributes
# 2             Player
# 3              Match
# 4             League
# 5            Country
# 6               Team
# 7    Team_Attributes

# %%
query = """SELECT *
            FROM Country; """

countries = pd.read_sql(query, conn)
countries
# Out:
#        id         name
# 0       1      Belgium
# 1    1729      England
# 2    4769       France
# 3    7809      Germany
# 4   10257        Italy
# 5   13274  Netherlands
# 6   15722       Poland
# 7   17642     Portugal
# 8   19694     Scotland
# 9   21518        Spain
# 10  24558  Switzerland

# %%
#Ingrese la consulta SQL entre un par de 3 comillas dobles: """consulta SQL""" justo después de la palabra query =

query = """SELECT *
            FROM League; """

#No modificar lo siguiente:
leagues = pd.read_sql(query, conn)
leagues
# Out:
#        id  country_id                      name
# 0       1           1    Belgium Jupiler League
# 1    1729        1729    England Premier League
# 2    4769        4769            France Ligue 1
# 3    7809        7809     Germany 1. Bundesliga
# 4   10257       10257             Italy Serie A
# 5   13274       13274    Netherlands Eredivisie
# 6   15722       15722        Poland Ekstraklasa
# 7   17642       17642  Portugal Liga ZON Sagres
# 8   19694       19694   Scotland Premier League
# 9   21518       21518           Spain LIGA BBVA
# 10  24558       24558  Switzerland Super League

# %%
query = """SELECT *
            FROM Player; """

#No modificar lo siguiente:
players = pd.read_sql(query, conn)
players
# Out:
#           id  player_api_id          player_name  player_fifa_api_id  \
# 0          1         505942   Aaron Appindangoye              218353
# 1          2         155782      Aaron Cresswell              189615
# 2          3         162549          Aaron Doran              186170
# 3          4          30572        Aaron Galindo              140161
# 4          5          23780         Aaron Hughes               17725
# ...      ...            ...                  ...                 ...
# 11055  11071          26357       Zoumana Camara                2488
# 11056  11072         111182         Zsolt Laczko              164680
# 11057  11073          36491            Zsolt Low              111191
# 11058  11074          35506  Zurab Khizanishvili               47058
# 11059  11075          39902   Zvjezdan Misimovic              102359
#
#                   birthday  height  weight
# 0      1992-02-29 00:00:00  182.88     187
# 1      1989-12-15 00:00:00  170.18     146
# 2      1991-05-13 00:00:00  170.18     163
# 3      1982-05-08 00:00:00  182.88     198
# 4      1979-11-08 00:00:00  182.88     154
# ...                    ...     ...     ...
# 11055  1979-04-03 00:00:00  182.88     168
# 11056  1986-12-18 00:00:00  182.88     176
# 11057  1979-04-29 00:00:00  180.34     154
# 11058  1981-10-06 00:00:00  185.42     172
# 11059  1982-06-05 00:00:00  180.34     176
#
# [11060 rows x 7 columns]

# %%
query = ("SELECT id, player_name, birthday, height, weight FROM Player LIMIT 10;")

#* deme todas las columnas
# Mostrar los resultados
players = pd.read_sql(query, conn)
players
# Out:
#    id         player_name             birthday  height  weight
# 0   1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# 1   2     Aaron Cresswell  1989-12-15 00:00:00  170.18     146
# 2   3         Aaron Doran  1991-05-13 00:00:00  170.18     163
# 3   4       Aaron Galindo  1982-05-08 00:00:00  182.88     198
# 4   5        Aaron Hughes  1979-11-08 00:00:00  182.88     154
# 5   6          Aaron Hunt  1986-09-04 00:00:00  182.88     161
# 6   7          Aaron Kuhl  1996-01-30 00:00:00  172.72     146
# 7   8        Aaron Lennon  1987-04-16 00:00:00  165.10     139
# 8   9        Aaron Lennox  1993-02-19 00:00:00  190.50     181
# 9  10       Aaron Meijers  1987-10-28 00:00:00  175.26     170

# %%
query = """
SELECT season
FROM Match;
"""
seasons = pd.read_sql(query, conn)
seasons
# Out:
#           season
# 0      2008/2009
# 1      2008/2009
# 2      2008/2009
# 3      2008/2009
# 4      2008/2009
# ...          ...
# 25974  2015/2016
# 25975  2015/2016
# 25976  2015/2016
# 25977  2015/2016
# 25978  2015/2016
#
# [25979 rows x 1 columns]

# %%
query = """
SELECT DISTINCT season
FROM Match;
"""
seasons = pd.read_sql(query, conn)
seasons

#Ingrese la la consulta SQL entre un par de 3 comillas dobles: """consulta SQL""" después de la palabra query =
# Out:
#       season
# 0  2008/2009
# 1  2009/2010
# 2  2010/2011
# 3  2011/2012
# 4  2012/2013
# 5  2013/2014
# 6  2014/2015
# 7  2015/2016

# %%
query = """
SELECT DISTINCT overall_rating
FROM Player_Attributes;"""

#No modificar lo siguiente:
overall_rating = pd.read_sql(query, conn)
overall_rating
# Out:
#     overall_rating
# 0             67.0
# 1             62.0
# 2             61.0
# 3             74.0
# 4             73.0
# ..             ...
# 57            33.0
# 58            36.0
# 59            37.0
# 60            35.0
# 61            94.0
#
# [62 rows x 1 columns]

# %%
query = """
SELECT id, player_name, birthday, height, weight
FROM Player
LIMIT 15;
"""
players = pd.read_sql(query, conn)
players
# Out:
#     id         player_name             birthday  height  weight
# 0    1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# 1    2     Aaron Cresswell  1989-12-15 00:00:00  170.18     146
# 2    3         Aaron Doran  1991-05-13 00:00:00  170.18     163
# 3    4       Aaron Galindo  1982-05-08 00:00:00  182.88     198
# 4    5        Aaron Hughes  1979-11-08 00:00:00  182.88     154
# 5    6          Aaron Hunt  1986-09-04 00:00:00  182.88     161
# 6    7          Aaron Kuhl  1996-01-30 00:00:00  172.72     146
# 7    8        Aaron Lennon  1987-04-16 00:00:00  165.10     139
# 8    9        Aaron Lennox  1993-02-19 00:00:00  190.50     181
# 9   10       Aaron Meijers  1987-10-28 00:00:00  175.26     170
# 10  11       Aaron Mokoena  1980-11-25 00:00:00  182.88     181
# 11  12          Aaron Mooy  1990-09-15 00:00:00  175.26     150
# 12  13      Aaron Muirhead  1990-08-30 00:00:00  187.96     168
# 13  14        Aaron Niguez  1989-04-26 00:00:00  170.18     143
# 14  15        Aaron Ramsey  1990-12-26 00:00:00  177.80     154

# %%
query = """
SELECT id, team_long_name
FROM Team
LIMIT 25;
"""
teams = pd.read_sql(query, conn)
teams
# Out:
#       id        team_long_name
# 0      1              KRC Genk
# 1      2          Beerschot AC
# 2      3      SV Zulte-Waregem
# 3      4      Sporting Lokeren
# 4      5     KSV Cercle Brugge
# 5      6        RSC Anderlecht
# 6      7              KAA Gent
# 7      8             RAEC Mons
# 8      9         FCV Dender EH
# 9     10     Standard de Liège
# 10    11           KV Mechelen
# 11    12        Club Brugge KV
# 12    13         KSV Roeselare
# 13    14           KV Kortrijk
# 14    15                Tubize
# 15    16  Royal Excel Mouscron
# 16    17          KVC Westerlo
# 17    18    Sporting Charleroi
# 18   614     Sint-Truidense VV
# 19  1034             Lierse SK
# 20  1042             KAS Eupen
# 21  1513   Oud-Heverlee Leuven
# 22  2004      Waasland-Beveren
# 23  2476           KV Oostende
# 24  2510  Royal Excel Mouscron

# %%
#Ingrese la la consulta SQL entre un par de 3 comillas dobles: """consulta SQL""" después de la palabra query =

query = """
SELECT COUNT(DISTINCT name)
FROM Country;
"""

#No modificar lo siguiente:
count_countries = pd.read_sql(query, conn)
count_countries
# Out:
#    COUNT(DISTINCT name)
# 0                    11

# %%
#Ingrese la la consulta SQL entre un par de 3 comillas dobles: """consulta SQL""" después de la palabra query =

query = """
SELECT COUNT(DISTINCT stage)
FROM Match;"""

#No modificar lo siguiente:
countdis_stages = pd.read_sql(query, conn)
countdis_stages
# Out:
#    COUNT(DISTINCT stage)
# 0                     38

# %%
#Ingrese la la consulta SQL entre un par de 3 comillas dobles: """consulta SQL""" después de la palabra query =

query = """
SELECT COUNT(DISTINCT name)
FROM Country;
"""

#No modificar lo siguiente:
count_countries = pd.read_sql(query, conn)
count_countries
# Out:
#    COUNT(DISTINCT name)
# 0                    11

# %%
query = """
SELECT COUNT(DISTINCT Stage)
FROM Match;
"""

#No modificar lo siguiente:
countdis_stages = pd.read_sql(query, conn)
countdis_stages
# Out:
#    COUNT(DISTINCT Stage)
# 0                     38

# %%
query = """
SELECT COUNT(DISTINCT away_team_goal)
FROM Match;
"""

#No modificar lo siguiente:
sum_awayteam = pd.read_sql(query, conn)
sum_awayteam
# Out:
#    COUNT(DISTINCT away_team_goal)
# 0                              10

# %%
query =  query = """
SELECT
    AVG(home_team_goal) AS promedio_goles_local,
    AVG(away_team_goal) AS promedio_goles_visitante
FROM Match;
"""

#No modificar lo siguiente:
avg_teamgoals = pd.read_sql(query, conn)
avg_teamgoals
# Out:
#    promedio_goles_local  promedio_goles_visitante
# 0              1.544594                  1.160938

# %%
query = """
SELECT MAX(away_team_goal) AS max_goles_visitante
FROM Match;
"""

# No modificar lo siguiente:
max_goles_visitante = pd.read_sql(query, conn)
max_goles_visitante
# Out:
#    max_goles_visitante
# 0                    9

# %%
query = """
SELECT AVG(home_team_goal + away_team_goal) AS promedio_goles_por_partido
FROM Match;
"""

# No modificar lo siguiente:
promedio_goles_por_partido = pd.read_sql(query, conn)
promedio_goles_por_partido
# Out:
#    promedio_goles_por_partido
# 0                    2.705531

# %%
query = """SELECT id, player_name, birthday, height, weight
        FROM Player
        WHERE weight = 165
        LIMIT 15;"""

players_weight = pd.read_sql(query, conn)
players_weight
# Out:
#      id          player_name             birthday  height  weight
# 0    27   Abdelmalek Cherrad  1981-01-14 00:00:00  185.42     165
# 1    44   Abdoulaye Doucoure  1993-01-01 00:00:00  182.88     165
# 2    46      Abdoulaye Keita  1994-01-05 00:00:00  175.26     165
# 3    49  Abdoulwahid Sissoko  1990-03-20 00:00:00  182.88     165
# 4    58   Abdullah Al Hafith  1992-12-25 00:00:00  187.96     165
# 5    62           Abel Gomez  1982-02-20 00:00:00  182.88     165
# 6    67                 Abel  1978-12-22 00:00:00  177.80     165
# 7    69         Abiola Dauda  1988-02-03 00:00:00  180.34     165
# 8    78     Abraham Paz Cruz  1979-03-14 00:00:00  177.80     165
# 9    84          Aco Stojkov  1983-04-29 00:00:00  177.80     165
# 10  110            Adam King  1995-10-11 00:00:00  180.34     165
# 11  119       Adam Matuschyk  1989-02-14 00:00:00  180.34     165
# 12  132            Adam Vass  1988-09-09 00:00:00  180.34     165
# 13  157        Adnan Januzaj  1995-02-05 00:00:00  182.88     165
# 14  169   Adrian Klepczynski  1981-04-01 00:00:00  187.96     165

# %%
query = """
SELECT season, home_team_goal, away_team_goal
FROM Match
WHERE away_team_goal >= 7;
"""

# No modificar lo siguiente:
resultados = pd.read_sql(query, conn)
resultados
# Out:
#        season  home_team_goal  away_team_goal
# 0   2012/2013               1               7
# 1   2014/2015               1               7
# 2   2014/2015               2               7
# 3   2015/2016               0               9
# 4   2010/2011               1               8
# 5   2013/2014               0               7
# 6   2010/2011               0               7
# 7   2013/2014               0               7
# 8   2010/2011               0               8
# 9   2011/2012               0               7
# 10  2014/2015               0               8
# 11  2014/2015               2               8
# 12  2015/2016               0               8
# 13  2008/2009               1               7
# 14  2009/2010               1               7
# 15  2015/2016               0               7

# %%
query = """
SELECT id, buildUpPlayDribblingClass, buildUpPlaySpeedClass
FROM Team_Attributes
WHERE buildUpPlayDribblingClass = 'Normal'
AND buildUpPlaySpeedClass = 'Balanced';
"""

# No modificar lo siguiente:
resultados = pd.read_sql(query, conn)
resultados
# Out:
#        id buildUpPlayDribblingClass buildUpPlaySpeedClass
# 0       2                    Normal              Balanced
# 1       3                    Normal              Balanced
# 2       8                    Normal              Balanced
# 3       9                    Normal              Balanced
# 4      14                    Normal              Balanced
# ..    ...                       ...                   ...
# 382  1450                    Normal              Balanced
# 383  1451                    Normal              Balanced
# 384  1452                    Normal              Balanced
# 385  1457                    Normal              Balanced
# 386  1458                    Normal              Balanced
#
# [387 rows x 3 columns]

# %%
#6.3.1
query = """
SELECT id, buildUpPlayPassingClass, buildUpPlaySpeedClass
FROM Team_Attributes
WHERE buildUpPlayPassingClass = 'Long'
AND buildUpPlaySpeedClass = 'Fast';
"""

# No modificar lo siguiente:
team_att_or = pd.read_sql(query, conn)
team_att_or
# Out:
#       id buildUpPlayPassingClass buildUpPlaySpeedClass
# 0      4                    Long                  Fast
# 1     90                    Long                  Fast
# 2    167                    Long                  Fast
# 3    179                    Long                  Fast
# 4    183                    Long                  Fast
# 5    225                    Long                  Fast
# 6    289                    Long                  Fast
# 7    336                    Long                  Fast
# 8    359                    Long                  Fast
# 9    419                    Long                  Fast
# 10   536                    Long                  Fast
# 11   555                    Long                  Fast
# 12   564                    Long                  Fast
# 13   586                    Long                  Fast
# 14   611                    Long                  Fast
# 15   612                    Long                  Fast
# 16   642                    Long                  Fast
# 17   713                    Long                  Fast
# 18   830                    Long                  Fast
# 19   853                    Long                  Fast
# 20   899                    Long                  Fast
# 21   908                    Long                  Fast
# 22  1002                    Long                  Fast
# 23  1014                    Long                  Fast
# 24  1037                    Long                  Fast
# 25  1216                    Long                  Fast
# 26  1239                    Long                  Fast
# 27  1245                    Long                  Fast
# 28  1246                    Long                  Fast
# 29  1367                    Long                  Fast
# 30  1388                    Long                  Fast
# 31  1389                    Long                  Fast
# 32  1399                    Long                  Fast
# 33  1421                    Long                  Fast
# 34  1423                    Long                  Fast

# %%
query = """
SELECT id, name
FROM Country
WHERE name <> 'Belgium';
"""

# No modificar lo siguiente:
countries_not = pd.read_sql(query, conn)
countries_not
# Out:
#       id         name
# 0   1729      England
# 1   4769       France
# 2   7809      Germany
# 3  10257        Italy
# 4  13274  Netherlands
# 5  15722       Poland
# 6  17642     Portugal
# 7  19694     Scotland
# 8  21518        Spain
# 9  24558  Switzerland

# %%
#Ingrese la la consulta SQL entre un par de 3 comillas dobles: """consulta SQL""" después de la palabra query =

query ="""
SELECT id, name
FROM Country
WHERE name = 'Italy';
"""

#No modificar lo siguiente:
countries_equal = pd.read_sql(query, conn)
countries_equal
# Out:
#       id   name
# 0  10257  Italy

# %%
query = """
SELECT id, name
FROM Country
WHERE name <> 'Poland';
"""
countries_dif = pd.read_sql(query, conn)
countries_dif
# Out:
#       id         name
# 0      1      Belgium
# 1   1729      England
# 2   4769       France
# 3   7809      Germany
# 4  10257        Italy
# 5  13274  Netherlands
# 6  17642     Portugal
# 7  19694     Scotland
# 8  21518        Spain
# 9  24558  Switzerland

# %%
query = """ SELECT season,
            Country.name
            League.name
            ROUND(AVG(Match.home_team_goal), 2)
            ROUND(AVG(Match.away_team_goal), 2)
            SUM(home_team_goal + away_team_goal)
       FROM Match
            JOIN Country ON Match.country_id = Country.id
            JOIN League ON Match.league_id = League.id
       WHERE Country.name IN ('Spain', 'France', 'England')
       GROUP BY season, League
       HAVING avg_local_goals BETWEEN 1.4 AND 1.6 AND avg_visitor_goals BETWEEN 1.2 AND 1.6
       ORDER BY season DESC;"""

goals_by_season = pd.read_sql(query, conn)
goals_by_season
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2673         try:
# -> 2674             cur.execute(sql, *args)
#    2675             return cur
#
# OperationalError: near ".": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-50-79d2f8c86be7> in <cell line: 15>()
#      13        ORDER BY season DESC;"""
#      14
# ---> 15 goals_by_season = pd.read_sql(query, conn)
#      16 goals_by_season
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     704     with pandasSQL_builder(con) as pandas_sql:
#     705         if isinstance(pandas_sql, SQLiteDatabase):
# --> 706             return pandas_sql.read_query(
#     707                 sql,
#     708                 index_col=index_col,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2736         dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2737     ) -> DataFrame | Iterator[DataFrame]:
# -> 2738         cursor = self.execute(sql, params)
#    2739         columns = [col_desc[0] for col_desc in cursor.description]
#    2740
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2684
#    2685             ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2686             raise ex from exc
#    2687
#    2688     @staticmethod
#
# DatabaseError: Execution failed on sql ' SELECT season,
#             Country.name
#             League.name
#             ROUND(AVG(Match.home_team_goal), 2)
#             ROUND(AVG(Match.away_team_goal), 2)
#             SUM(home_team_goal + away_team_goal)
#        FROM Match
#             JOIN Country ON Match.country_id = Country.id
#             JOIN League ON Match.league_id = League.id
#        WHERE Country.name IN ('Spain', 'France', 'England')
#        GROUP BY season, League
#        HAVING avg_local_goals BETWEEN 1.4 AND 1.6 AND avg_visitor_goals BETWEEN 1.2 AND 1.6
#        ORDER BY season DESC;': near ".": syntax error

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Crear la gráfica
plt.figure(figsize=(8, 4))
sns.lineplot(data=goals_by_season, x='season', y='avg_local_goals', hue='Country', marker='o')
sns.lineplot(data=goals_by_season, x='season', y='avg_visitor_goals', hue='Country', marker='x')

plt.title('Promedio de Goles por Temporada y País')
plt.xlabel('Temporada')
plt.ylabel('Promedio de Goles')
plt.legend(title='País')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-bf5da51fae2d> in <cell line: 5>()
#       3 # Crear la gráfica
#       4 plt.figure(figsize=(8, 4))
# ----> 5 sns.lineplot(data=goals_by_season, x='season', y='avg_local_goals', hue='Country', marker='o')
#       6 sns.lineplot(data=goals_by_season, x='season', y='avg_visitor_goals', hue='Country', marker='x')
#       7
#
# NameError: name 'goals_by_season' is not defined
