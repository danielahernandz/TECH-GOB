# %%
import os
import altair as alt
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# import pyodbc
import warnings
import sqlite3

# %%
data  = pd.read_csv('acumulado_saber_11.csv')
data
# Out:
#        ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO  \
# 0                      CC          COLOMBIA           F
# 1                      TI          COLOMBIA           M
# 2                      TI          COLOMBIA           M
# 3                      TI          COLOMBIA           F
# 4                      TI          COLOMBIA           F
# ...                   ...               ...         ...
# 139290                 TI          COLOMBIA           M
# 139291                 CC          COLOMBIA           M
# 139292                 TI          COLOMBIA           M
# 139293                 TI          COLOMBIA           M
# 139294                 TI          COLOMBIA           M
#
#           ESTU_FECHANACIMIENTO  PERIODO  ESTU_CONSECUTIVO ESTU_PAIS_RESIDE  \
# 0                   29/09/1999    20181  SB11201810007354         COLOMBIA
# 1                   19/03/2001    20181  SB11201810018765         COLOMBIA
# 2                   31/07/2000    20181  SB11201810028523         COLOMBIA
# 3                   20/01/2002    20181  SB11201810003574         COLOMBIA
# 4                   23/10/2001    20181  SB11201810024346         COLOMBIA
# ...                        ...      ...               ...              ...
# 139290  09/08/2002 12:00:00 AM    20194  SB11201940213889         COLOMBIA
# 139291  02/06/2001 12:00:00 AM    20194  SB11201940182325         COLOMBIA
# 139292  10/28/2002 12:00:00 AM    20194  SB11201940108759         COLOMBIA
# 139293  05/26/2002 12:00:00 AM    20194  SB11201940630298         COLOMBIA
# 139294  05/07/2003 12:00:00 AM    20194  SB11201940144720         COLOMBIA
#
#        ESTU_TIENEETNIA ESTU_DEPTO_RESIDE ESTU_MCPIO_RESIDE  ...  \
# 0                   No            BOGOTA       BOGOTÁ D.C.  ...
# 1                   No             VALLE              CALI  ...
# 2                   No             VALLE              CALI  ...
# 3                   No             VALLE              CALI  ...
# 4                   No             VALLE              CALI  ...
# ...                ...               ...               ...  ...
# 139290              No           BOLIVAR           TURBACO  ...
# 139291              No           BOLIVAR   HATILLO DE LOBA  ...
# 139292              Si             CHOCO            ACANDÍ  ...
# 139293              No         ATLANTICO           SOLEDAD  ...
# 139294              No   NORTE SANTANDER           TEORAMA  ...
#
#             COLE_CARACTER COLE_AREA_UBICACION COLE_JORNADA  \
# 0               ACADÉMICO              URBANO     COMPLETA
# 1               ACADÉMICO              URBANO     COMPLETA
# 2               NO APLICA               RURAL     SABATINA
# 3               ACADÉMICO              URBANO     COMPLETA
# 4               ACADÉMICO              URBANO       MAÑANA
# ...                   ...                 ...          ...
# 139290            TÉCNICO               RURAL       MAÑANA
# 139291          ACADÉMICO               RURAL       MAÑANA
# 139292  TÉCNICO/ACADÉMICO              URBANO        UNICA
# 139293  TÉCNICO/ACADÉMICO              URBANO        UNICA
# 139294         TÉCNICO/AC                 NaN          NaN
#
#        ESTU_PRIVADO_LIBERTAD PUNT_LECTURA_CRITICA PUNT_MATEMATICAS  \
# 0                          N                 71.0             65.0
# 1                          N                 75.0             77.0
# 2                          N                 42.0             27.0
# 3                          N                 61.0             62.0
# 4                          N                 69.0             75.0
# ...                      ...                  ...              ...
# 139290                     N                 44.0             49.0
# 139291                     N                 51.0             57.0
# 139292                     N                 52.0             40.0
# 139293                     N                 62.0             72.0
# 139294                   NaN                  NaN              NaN
#
#        PUNT_C_NATURALES PUNT_SOCIALES_CIUDADANAS PUNT_INGLES PUNT_GLOBAL
# 0                  69.0                     63.0        90.0       344.0
# 1                 100.0                     81.0        86.0       417.0
# 2                  29.0                     36.0        29.0       166.0
# 3                  72.0                     70.0        79.0       336.0
# 4                  67.0                     65.0        71.0       346.0
# ...                 ...                      ...         ...         ...
# 139290             40.0                     33.0        46.0       209.0
# 139291             54.0                     38.0        38.0       245.0
# 139292             44.0                     24.0        34.0       198.0
# 139293             56.0                     63.0        62.0       316.0
# 139294              NaN                      NaN         NaN         NaN
#
# [139295 rows x 40 columns]

# %%
df = pd.DataFrame(data)
df
# Out:
#        ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO  \
# 0                      CC          COLOMBIA           F
# 1                      TI          COLOMBIA           M
# 2                      TI          COLOMBIA           M
# 3                      TI          COLOMBIA           F
# 4                      TI          COLOMBIA           F
# ...                   ...               ...         ...
# 139290                 TI          COLOMBIA           M
# 139291                 CC          COLOMBIA           M
# 139292                 TI          COLOMBIA           M
# 139293                 TI          COLOMBIA           M
# 139294                 TI          COLOMBIA           M
#
#           ESTU_FECHANACIMIENTO  PERIODO  ESTU_CONSECUTIVO ESTU_PAIS_RESIDE  \
# 0                   29/09/1999    20181  SB11201810007354         COLOMBIA
# 1                   19/03/2001    20181  SB11201810018765         COLOMBIA
# 2                   31/07/2000    20181  SB11201810028523         COLOMBIA
# 3                   20/01/2002    20181  SB11201810003574         COLOMBIA
# 4                   23/10/2001    20181  SB11201810024346         COLOMBIA
# ...                        ...      ...               ...              ...
# 139290  09/08/2002 12:00:00 AM    20194  SB11201940213889         COLOMBIA
# 139291  02/06/2001 12:00:00 AM    20194  SB11201940182325         COLOMBIA
# 139292  10/28/2002 12:00:00 AM    20194  SB11201940108759         COLOMBIA
# 139293  05/26/2002 12:00:00 AM    20194  SB11201940630298         COLOMBIA
# 139294  05/07/2003 12:00:00 AM    20194  SB11201940144720         COLOMBIA
#
#        ESTU_TIENEETNIA ESTU_DEPTO_RESIDE ESTU_MCPIO_RESIDE  ...  \
# 0                   No            BOGOTA       BOGOTÁ D.C.  ...
# 1                   No             VALLE              CALI  ...
# 2                   No             VALLE              CALI  ...
# 3                   No             VALLE              CALI  ...
# 4                   No             VALLE              CALI  ...
# ...                ...               ...               ...  ...
# 139290              No           BOLIVAR           TURBACO  ...
# 139291              No           BOLIVAR   HATILLO DE LOBA  ...
# 139292              Si             CHOCO            ACANDÍ  ...
# 139293              No         ATLANTICO           SOLEDAD  ...
# 139294              No   NORTE SANTANDER           TEORAMA  ...
#
#             COLE_CARACTER COLE_AREA_UBICACION COLE_JORNADA  \
# 0               ACADÉMICO              URBANO     COMPLETA
# 1               ACADÉMICO              URBANO     COMPLETA
# 2               NO APLICA               RURAL     SABATINA
# 3               ACADÉMICO              URBANO     COMPLETA
# 4               ACADÉMICO              URBANO       MAÑANA
# ...                   ...                 ...          ...
# 139290            TÉCNICO               RURAL       MAÑANA
# 139291          ACADÉMICO               RURAL       MAÑANA
# 139292  TÉCNICO/ACADÉMICO              URBANO        UNICA
# 139293  TÉCNICO/ACADÉMICO              URBANO        UNICA
# 139294         TÉCNICO/AC                 NaN          NaN
#
#        ESTU_PRIVADO_LIBERTAD PUNT_LECTURA_CRITICA PUNT_MATEMATICAS  \
# 0                          N                 71.0             65.0
# 1                          N                 75.0             77.0
# 2                          N                 42.0             27.0
# 3                          N                 61.0             62.0
# 4                          N                 69.0             75.0
# ...                      ...                  ...              ...
# 139290                     N                 44.0             49.0
# 139291                     N                 51.0             57.0
# 139292                     N                 52.0             40.0
# 139293                     N                 62.0             72.0
# 139294                   NaN                  NaN              NaN
#
#        PUNT_C_NATURALES PUNT_SOCIALES_CIUDADANAS PUNT_INGLES PUNT_GLOBAL
# 0                  69.0                     63.0        90.0       344.0
# 1                 100.0                     81.0        86.0       417.0
# 2                  29.0                     36.0        29.0       166.0
# 3                  72.0                     70.0        79.0       336.0
# 4                  67.0                     65.0        71.0       346.0
# ...                 ...                      ...         ...         ...
# 139290             40.0                     33.0        46.0       209.0
# 139291             54.0                     38.0        38.0       245.0
# 139292             44.0                     24.0        34.0       198.0
# 139293             56.0                     63.0        62.0       316.0
# 139294              NaN                      NaN         NaN         NaN
#
# [139295 rows x 40 columns]

# %%
# Consulta y validación de la cantidad de filas y columnas del dataframe
num_rows, num_cols = df.shape
num_rows, num_cols
# Out:
# (139295, 40)

# %%
# La función sample, devuelve la cantidad aleatorias de filas/registros solicitada del dataframe
df.sample(15)
# Out:
#        ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO  \
# 19452                  CC          COLOMBIA           F
# 83151                  TI          COLOMBIA           F
# 40249                  TI          COLOMBIA           M
# 79057                  TI          COLOMBIA           M
# 42102                  TI          COLOMBIA           F
# 13415                  TI          COLOMBIA           M
# 24867                  TI          COLOMBIA           M
# 105571                 TI          COLOMBIA           M
# 16361                  TI          COLOMBIA           M
# 56932                  TI          COLOMBIA           F
# 96208                  TI          COLOMBIA           F
# 40653                  CC          COLOMBIA           F
# 110354                 TI          COLOMBIA           F
# 20476                  TI          COLOMBIA           M
# 75311                  TI          COLOMBIA           M
#
#           ESTU_FECHANACIMIENTO  PERIODO  ESTU_CONSECUTIVO ESTU_PAIS_RESIDE  \
# 19452               23/01/1980    20181  SB11201810033710         COLOMBIA
# 83151   01/18/2002 12:00:00 AM    20194  SB11201940406072         COLOMBIA
# 40249   09/21/1999 12:00:00 AM    20194  SB11201940005139         COLOMBIA
# 79057   02/15/2002 12:00:00 AM    20194  SB11201940541955         COLOMBIA
# 42102   02/17/2003 12:00:00 AM    20194  SB11201940429586         COLOMBIA
# 13415               04/02/2000    20181  SB11201810002897         COLOMBIA
# 24867   08/09/1999 12:00:00 AM    20194  SB11201940541444         COLOMBIA
# 105571  09/08/2001 12:00:00 AM    20194  SB11201940512290         COLOMBIA
# 16361               13/09/2001    20181  SB11201810018362         COLOMBIA
# 56932   04/16/2002 12:00:00 AM    20194  SB11201940044120         COLOMBIA
# 96208   10/04/2004 12:00:00 AM    20194  SB11201940325860         COLOMBIA
# 40653   12/05/2000 12:00:00 AM    20194  SB11201940260290         COLOMBIA
# 110354  03/21/2003 12:00:00 AM    20194  SB11201940435638         COLOMBIA
# 20476   04/06/2002 12:00:00 AM    20194  SB11201940571386         COLOMBIA
# 75311   09/07/2001 12:00:00 AM    20194  SB11201940330947         COLOMBIA
#
#        ESTU_TIENEETNIA ESTU_DEPTO_RESIDE    ESTU_MCPIO_RESIDE  ...  \
# 19452               No            CALDAS            LA DORADA  ...
# 83151               No             HUILA             PITALITO  ...
# 40249               Si            NARIÑO            EL CHARCO  ...
# 79057               No           BOLIVAR  CARTAGENA DE INDIAS  ...
# 42102               No            BOGOTÁ          BOGOTÁ D.C.  ...
# 13415               No         ATLANTICO         BARRANQUILLA  ...
# 24867               No            NARIÑO    FRANCISCO PIZARRO  ...
# 105571              No             HUILA             PITALITO  ...
# 16361               No             VALLE                 CALI  ...
# 56932               No            BOYACA            VIRACACHÁ  ...
# 96208               No         MAGDALENA          SANTA MARTA  ...
# 40653               No         MAGDALENA                PLATO  ...
# 110354              No         ATLANTICO         BARRANQUILLA  ...
# 20476               No         MAGDALENA          SANTA MARTA  ...
# 75311               No            BOGOTÁ          BOGOTÁ D.C.  ...
#
#             COLE_CARACTER COLE_AREA_UBICACION COLE_JORNADA  \
# 19452           ACADÉMICO              URBANO        NOCHE
# 83151           ACADÉMICO               RURAL     SABATINA
# 40249           ACADÉMICO              URBANO       MAÑANA
# 79057   TÉCNICO/ACADÉMICO              URBANO        TARDE
# 42102           ACADÉMICO              URBANO       MAÑANA
# 13415           ACADÉMICO              URBANO     COMPLETA
# 24867           ACADÉMICO              URBANO       MAÑANA
# 105571                NaN               RURAL     COMPLETA
# 16361           ACADÉMICO              URBANO     COMPLETA
# 56932   TÉCNICO/ACADÉMICO              URBANO     COMPLETA
# 96208           ACADÉMICO               RURAL        TARDE
# 40653   TÉCNICO/ACADÉMICO              URBANO        UNICA
# 110354          ACADÉMICO              URBANO       MAÑANA
# 20476           ACADÉMICO              URBANO        TARDE
# 75311           ACADÉMICO              URBANO     COMPLETA
#
#        ESTU_PRIVADO_LIBERTAD PUNT_LECTURA_CRITICA PUNT_MATEMATICAS  \
# 19452                      N                 49.0             42.0
# 83151                      N                 40.0             41.0
# 40249                      N                 50.0             47.0
# 79057                      N                 31.0             37.0
# 42102                      N                 61.0             58.0
# 13415                      N                 77.0             83.0
# 24867                      N                 56.0             39.0
# 105571                     N                 46.0             52.0
# 16361                      N                 50.0             46.0
# 56932                      N                 52.0             46.0
# 96208                      N                 40.0             37.0
# 40653                      N                 47.0             41.0
# 110354                     N                 58.0             57.0
# 20476                      N                 42.0             50.0
# 75311                      N                 54.0             50.0
#
#        PUNT_C_NATURALES PUNT_SOCIALES_CIUDADANAS PUNT_INGLES PUNT_GLOBAL
# 19452              44.0                     57.0        68.0       248.0
# 83151              34.0                     33.0        42.0       187.0
# 40249              40.0                     45.0        54.0       231.0
# 79057              31.0                     37.0        24.0       166.0
# 42102              58.0                     53.0        65.0       290.0
# 13415              75.0                     78.0        90.0       396.0
# 24867              35.0                     42.0        34.0       212.0
# 105571             37.0                     34.0        39.0       210.0
# 16361              50.0                     51.0        54.0       248.0
# 56932              42.0                     38.0        50.0       225.0
# 96208              42.0                     31.0        35.0       187.0
# 40653              38.0                     34.0        35.0       198.0
# 110354             53.0                     45.0        40.0       261.0
# 20476              41.0                     34.0        39.0       208.0
# 75311              43.0                     40.0        45.0       233.0
#
# [15 rows x 40 columns]

# %%
df['ESTU_DEPTO_RESIDE'].value_counts()
# Out:
# ESTU_DEPTO_RESIDE
# BOGOTÁ             19389
# VALLE              15863
# ANTIOQUIA          15842
# CUNDINAMARCA        8840
# ATLANTICO           8209
# SANTANDER           5827
# BOLIVAR             5775
# BOGOTA              5403
# NARIÑO              4654
# CORDOBA             4644
# MAGDALENA           4020
# BOYACA              3946
# CAUCA               3863
# TOLIMA              3682
# NORTE SANTANDER     3567
# CESAR               3200
# HUILA               3091
# META                2854
# SUCRE               2473
# RISARALDA           2446
# CALDAS              2429
# LA GUAJIRA          1973
# CASANARE            1361
# QUINDIO             1352
# CAQUETA             1108
# PUTUMAYO             925
# CHOCO                920
# ARAUCA               788
# GUAVIARE             194
# AMAZONAS             175
# SAN ANDRES           128
# VICHADA               94
# GUAINIA               68
# VAUPES                56
# EXTRANJERO            32
# -                     16
# Name: count, dtype: int64

# %% [markdown]
# Análisis basico

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139295 entries, 0 to 139294
# Data columns (total 40 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   ESTU_TIPODOCUMENTO            139295 non-null  object
#  1   ESTU_NACIONALIDAD             139295 non-null  object
#  2   ESTU_GENERO                   139295 non-null  object
#  3   ESTU_FECHANACIMIENTO          139293 non-null  object
#  4   PERIODO                       139295 non-null  int64
#  5   ESTU_CONSECUTIVO              139295 non-null  object
#  6   ESTU_PAIS_RESIDE              139295 non-null  object
#  7   ESTU_TIENEETNIA               139295 non-null  object
#  8   ESTU_DEPTO_RESIDE             139207 non-null  object
#  9   ESTU_MCPIO_RESIDE             139207 non-null  object
#  10  FAMI_ESTRATOVIVIENDA          139286 non-null  object
#  11  FAMI_PERSONASHOGAR            137450 non-null  object
#  12  FAMI_CUARTOSHOGAR             137897 non-null  object
#  13  FAMI_EDUCACIONPADRE           137484 non-null  object
#  14  FAMI_EDUCACIONMADRE           134823 non-null  object
#  15  FAMI_TRABAJOLABORPADRE        137514 non-null  object
#  16  FAMI_TRABAJOLABORMADRE        137660 non-null  object
#  17  FAMI_TIENEINTERNET            137471 non-null  object
#  18  FAMI_TIENECOMPUTADOR          137506 non-null  object
#  19  FAMI_TIENECONSOLAVIDEOJUEGOS  137636 non-null  object
#  20  FAMI_NUMLIBROS                137434 non-null  object
#  21  FAMI_SITUACIONECONOMICA       137496 non-null  object
#  22  ESTU_DEDICACIONLECTURADIARIA  139166 non-null  object
#  23  ESTU_DEDICACIONINTERNET       132741 non-null  object
#  24  ESTU_HORASSEMANATRABAJA       139219 non-null  object
#  25  ESTU_TIPOREMUNERACION         135886 non-null  object
#  26  COLE_NOMBRE_ESTABLECIMIENTO   139295 non-null  object
#  27  COLE_GENERO                   139295 non-null  object
#  28  COLE_NATURALEZA               139295 non-null  object
#  29  COLE_BILINGUE                 139295 non-null  object
#  30  COLE_CARACTER                 136260 non-null  object
#  31  COLE_AREA_UBICACION           139294 non-null  object
#  32  COLE_JORNADA                  139294 non-null  object
#  33  ESTU_PRIVADO_LIBERTAD         139294 non-null  object
#  34  PUNT_LECTURA_CRITICA          139294 non-null  float64
#  35  PUNT_MATEMATICAS              139294 non-null  float64
#  36  PUNT_C_NATURALES              139294 non-null  float64
#  37  PUNT_SOCIALES_CIUDADANAS      139294 non-null  float64
#  38  PUNT_INGLES                   139292 non-null  float64
#  39  PUNT_GLOBAL                   139294 non-null  float64
# dtypes: float64(6), int64(1), object(33)
# memory usage: 42.5+ MB

# %%
# Descripción estadística de las variables numérica
df.describe()
# Out:
#              PERIODO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# count  139295.000000         139294.000000     139294.000000
# mean    20192.152310             53.265977         51.718681
# std         4.539401             10.908696         12.601953
# min     20181.000000              0.000000          0.000000
# 25%     20194.000000             45.000000         43.000000
# 50%     20194.000000             53.000000         52.000000
# 75%     20194.000000             61.000000         61.000000
# max     20194.000000            100.000000        100.000000
#
#        PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS    PUNT_INGLES  \
# count     139294.000000             139294.000000  139292.000000
# mean          49.606408                 47.768971      50.385873
# std           11.489768                 12.828404      14.195290
# min            0.000000                  0.000000       0.000000
# 25%           41.000000                 38.000000      40.000000
# 50%           49.000000                 47.000000      49.000000
# 75%           58.000000                 57.000000      59.000000
# max          100.000000                100.000000     100.000000
#
#          PUNT_GLOBAL
# count  139294.000000
# mean      252.878853
# std        55.033451
# min        21.000000
# 25%       211.000000
# 50%       249.000000
# 75%       291.000000
# max       475.000000

# %%
# Descripción estadística de las variables numéricas sin notación científica
#UN DECIMAL
# Se define función lambda que toma un número x y devuelve ese número formateado con 1 decimal.
pd.set_option('display.float_format', lambda x: '%.1f' % x)

df.describe()
# Out:
#        PERIODO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  PUNT_C_NATURALES  \
# count 139295.0              139294.0          139294.0          139294.0
# mean   20192.2                  53.3              51.7              49.6
# std        4.5                  10.9              12.6              11.5
# min    20181.0                   0.0               0.0               0.0
# 25%    20194.0                  45.0              43.0              41.0
# 50%    20194.0                  53.0              52.0              49.0
# 75%    20194.0                  61.0              61.0              58.0
# max    20194.0                 100.0             100.0             100.0
#
#        PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# count                  139294.0     139292.0     139294.0
# mean                       47.8         50.4        252.9
# std                        12.8         14.2         55.0
# min                         0.0          0.0         21.0
# 25%                        38.0         40.0        211.0
# 50%                        47.0         49.0        249.0
# 75%                        57.0         59.0        291.0
# max                       100.0        100.0        475.0

# %% [markdown]
# - Periodo:
#     - La mayoría de los datos parecen concentrarse en el año 2019 y 2020, ya que los cuartiles y la media están más cerca de estos años.
#
# - Puntuaciones:
#     - Las puntuaciones mínimas para todas las asignaturas son 0, lo que indica que hay estudiantes que obtuvieron la puntuación más baja posible en estas materias.
#
#     - Las medias para todas las puntuaciones de las asignaturas están en un rango similar, alrededor de 45-52, lo que sugiere que los estudiantes, en promedio, tienen un rendimiento medio en estas asignaturas.
#
#     - Las desviaciones estándar son relativamente altas para todas las puntuaciones, lo que indica que hay una variabilidad significativa en las puntuaciones de los estudiantes.
#
#     - Las puntuaciones máximas para todas las materias son 100, lo que sugiere que hay estudiantes que obtuvieron la puntuación máxima posible.
#
#     - Las puntuaciones se encuentran en un rango de 0 a 500 para PUNT_GLOBAL, lo cual es un rango más amplio en comparación con las puntuaciones individuales de las asignaturas. Esto podría indicar que PUNT_GLOBAL es una combinación ponderada de las puntuaciones individuales o posiblemente incluye otros componentes no especificados en el conjunto de datos.
#
#     - Existen variabilidades significativas en las puntuaciones de los estudiantes, con algunos obteniendo puntuaciones muy bajas y otros muy altas. Esto podría indicar diferencias en la preparación, el esfuerzo o la capacidad de los estudiantes.
#
#     - Sería importante investigar más sobre la columna PUNT_GLOBAL para entender cómo se calcula y qué componentes incluye, ya que tiene un rango más amplio que las puntuaciones individuales de las materias.

# %%
#Descripción variables categoricas
df.describe(include=['object'])
# Out:
#        ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO  \
# count              139295            139295      139295
# unique                 10                28           3
# top                    TI          COLOMBIA           M
# freq               111743            138855       70308
#
#           ESTU_FECHANACIMIENTO  ESTU_CONSECUTIVO ESTU_PAIS_RESIDE  \
# count                   139293            139295           139295
# unique                    9196            139295               28
# top     01/01/1900 12:00:00 AM  SB11201810007354         COLOMBIA
# freq                       421                 1           138855
#
#        ESTU_TIENEETNIA ESTU_DEPTO_RESIDE ESTU_MCPIO_RESIDE  \
# count           139295            139207            139207
# unique               3                36              1031
# top                 No            BOGOTÁ       BOGOTÁ D.C.
# freq            130589             19389             24792
#
#        FAMI_ESTRATOVIVIENDA  ... ESTU_HORASSEMANATRABAJA  \
# count                139286  ...                  139219
# unique                    8  ...                       6
# top               Estrato 2  ...                       0
# freq                  45150  ...                   91391
#
#        ESTU_TIPOREMUNERACION                     COLE_NOMBRE_ESTABLECIMIENTO  \
# count                 135886                                          139295
# unique                     5                                            9430
# top                       No  INSTITUCION EDUCATIVA FRANCISCO JOSE DE CALDAS
# freq                   96389                                             268
#
#        COLE_GENERO COLE_NATURALEZA COLE_BILINGUE COLE_CARACTER  \
# count       139295          139295        139295        136260
# unique           3               2             3             6
# top          MIXTO         OFICIAL             N     ACADÉMICO
# freq        134098           91752        111897         77850
#
#        COLE_AREA_UBICACION COLE_JORNADA ESTU_PRIVADO_LIBERTAD
# count               139294       139294                139294
# unique                   2            6                     2
# top                 URBANO       MAÑANA                     N
# freq                118879        62118                139255
#
# [4 rows x 33 columns]

# %%
# Identificar valores únicos por columna
print("\nValores únicos por columna:")
for column in df.columns:
    unique = df[column].unique()
    print(f"\n{column} ({len(unique)} valores únicos):\n{unique[:10]}")
    if len(unique) > 10:
        print("...")
# Out:
# Valores únicos por columna:
#
# ESTU_TIPODOCUMENTO (10 valores únicos):
# ['CC' 'TI' 'CR' 'CE' 'PE' 'PC' 'RC' 'PEP' 'NES' 'CCB']
#
# ESTU_NACIONALIDAD (28 valores únicos):
# ['COLOMBIA' 'ESTADOS UNIDOS' 'BRASIL' 'PANAMÁ' 'VENEZUELA' 'ECUADOR'
#  'NICARAGUA' 'ESPAÑA' 'ARGENTINA' 'MÉXICO']
# ...
#
# ESTU_GENERO (3 valores únicos):
# ['F' 'M' '-']
#
# ESTU_FECHANACIMIENTO (9197 valores únicos):
# ['29/09/1999' '19/03/2001' '31/07/2000' '20/01/2002' '23/10/2001'
#  '20/04/2001' '05/04/2000' '05/11/2001' '03/11/2000' '23/09/1999']
# ...
#
# PERIODO (2 valores únicos):
# [20181 20194]
#
# ESTU_CONSECUTIVO (139295 valores únicos):
# ['SB11201810007354' 'SB11201810018765' 'SB11201810028523'
#  'SB11201810003574' 'SB11201810024346' 'SB11201810006862'
#  'SB11201810017023' 'SB11201810048390' 'SB11201810010098'
#  'SB11201810012063']
# ...
#
# ESTU_PAIS_RESIDE (28 valores únicos):
# ['COLOMBIA' 'ESTADOS UNIDOS' 'BRASIL' 'PANAMÁ' 'VENEZUELA' 'ECUADOR'
#  'NICARAGUA' 'ESPAÑA' 'ARGENTINA' 'MÉXICO']
# ...
#
# ESTU_TIENEETNIA (3 valores únicos):
# ['No' 'Si' '-']
#
# ESTU_DEPTO_RESIDE (37 valores únicos):
# ['BOGOTA' 'VALLE' 'ATLANTICO' 'CUNDINAMARCA' 'ANTIOQUIA' 'RISARALDA'
#  'CAUCA' 'BOLIVAR' 'CAQUETA' 'NORTE SANTANDER']
# ...
#
# ESTU_MCPIO_RESIDE (1032 valores únicos):
# ['BOGOTÁ D.C.' 'CALI' 'YUMBO' 'SOLEDAD' 'CHÍA' 'ENVIGADO' 'PALMIRA'
#  'BARRANQUILLA' 'EL CERRITO' 'PEREIRA']
# ...
#
# FAMI_ESTRATOVIVIENDA (9 valores únicos):
# ['Estrato 6' 'Estrato 5' 'Estrato 1' 'Estrato 3' 'Estrato 2' 'Sin Estrato'
#  'Estrato 4' '-' nan]
#
# FAMI_PERSONASHOGAR (8 valores únicos):
# ['3 a 4' '1 a 2' '5 a 6' 'Sin Respuesta' '9 o más' '7 a 8' '-' nan]
#
# FAMI_CUARTOSHOGAR (9 valores únicos):
# ['Tres' 'Dos' 'Sin respuesta' 'Cinco' 'Seis o mas' 'Cuatro' 'Uno' nan '-']
#
# FAMI_EDUCACIONPADRE (15 valores únicos):
# ['Educación profesional completa' 'Postgrado'
#  'Secundaria (Bachillerato) completa' 'Técnica o tecnológica incompleta'
#  'Sin respuesta' 'Primaria incompleta'
#  'Secundaria (Bachillerato) incompleta' 'Técnica o tecnológica completa'
#  'Primaria completa' 'No sabe']
# ...
#
# FAMI_EDUCACIONMADRE (15 valores únicos):
# ['Educación profesional completa' 'Secundaria (Bachillerato) completa'
#  'Postgrado' 'Técnica o tecnológica incompleta' 'Sin respuesta'
#  'Primaria incompleta' 'Secundaria (Bachillerato) incompleta'
#  'Técnica o tecnológica completa' 'Primaria completa' 'No sabe']
# ...
#
# FAMI_TRABAJOLABORPADRE (16 valores únicos):
# ['Trabaja como profesional (por ejemplo médico, abogado, ingeniero)'
#  'Trabaja por cuenta propia (por ejemplo plomero, electricista)'
#  'Trabaja en el hogar, no trabaja o estudia'
#  'Tiene un trabajo de tipo auxiliar administrativo (por ejemplo, secretario o asistente)'
#  'Es operario de máquinas o conduce vehículos (taxita, chofer)'
#  'Sin respuesta'
#  'Es dueño de un negocio pequeño (tiene pocos empleados o no tiene, por ejemplo tienda, papelería, etc'
#  'Es dueño de un negocio grande, tiene un cargo de nivel directivo o gerencial'
#  'No aplica' 'Pensionado']
# ...
#
# FAMI_TRABAJOLABORMADRE (16 valores únicos):
# ['Trabaja como profesional (por ejemplo médico, abogado, ingeniero)'
#  'Trabaja en el hogar, no trabaja o estudia'
#  'Es dueño de un negocio grande, tiene un cargo de nivel directivo o gerencial'
#  'Tiene un trabajo de tipo auxiliar administrativo (por ejemplo, secretario o asistente)'
#  'Es vendedor o trabaja en atención al público' 'Sin respuesta'
#  'Es agricultor, pesquero o jornalero'
#  'Es operario de máquinas o conduce vehículos (taxita, chofer)'
#  'Es dueño de un negocio pequeño (tiene pocos empleados o no tiene, por ejemplo tienda, papelería, etc'
#  'Trabaja como personal de limpieza, mantenimiento, seguridad o construcción']
# ...
#
# FAMI_TIENEINTERNET (5 valores únicos):
# ['Si' 'No' 'Sin respuesta' '-' nan]
#
# FAMI_TIENECOMPUTADOR (4 valores únicos):
# ['Si' 'No' '-' nan]
#
# FAMI_TIENECONSOLAVIDEOJUEGOS (4 valores únicos):
# ['Si' 'No' '-' nan]
#
# FAMI_NUMLIBROS (6 valores únicos):
# ['MÁS DE 100 LIBROS' '26 A 100 LIBROS' '0 A 10 LIBROS' '11 A 25 LIBROS'
#  '-' nan]
#
# FAMI_SITUACIONECONOMICA (5 valores únicos):
# ['Igual' 'Mejor' 'Peor' '-' nan]
#
# ESTU_DEDICACIONLECTURADIARIA (7 valores únicos):
# ['Entre 1 y 2 horas' 'No leo por entretenimiento' '30 minutos o menos'
#  'Entre 30 y 60 minutos' '-' 'Más de 2 horas' nan]
#
# ESTU_DEDICACIONINTERNET (7 valores únicos):
# ['Entre 1 y 3 horas' 'Entre 30 y 60 minutos' 'Más de 3 horas'
#  '30 minutos o menos' '-' 'No Navega Internet' nan]
#
# ESTU_HORASSEMANATRABAJA (7 valores únicos):
# ['0' 'Entre 11 y 20 horas' '-' 'Menos de 10 horas' 'Más de 30 horas'
#  'Entre 21 y 30 horas' nan]
#
# ESTU_TIPOREMUNERACION (6 valores únicos):
# ['No' 'Si, en efectivo' '-' 'Si, en especie' 'Si, en efectivo y especie'
#  nan]
#
# COLE_NOMBRE_ESTABLECIMIENTO (9430 valores únicos):
# ['GIMN VERMONT' 'COLEGIO PHILADELPHIA INTERNACIONAL'
#  'INST TECNOLG EMPRESARIAL COLOMBIANO' 'SANTA  MARIA STELLA MARIS'
#  'COLEGIO DE SAN LUIS GONZAGA' 'COL COMFANDI - YUMBO' 'COL COLOMBO GALES'
#  'LICEO MIXTO PARA ADULTOS JOSE PRUDENCIO PADILLA'
#  'NUEVO GIMNASIO CRISTIANO' 'CENTRO EDUCATIVO DE ADULTOS CEAM']
# ...
#
# COLE_GENERO (3 valores únicos):
# ['MIXTO' 'FEMENINO' 'MASCULINO']
#
# COLE_NATURALEZA (2 valores únicos):
# ['NO OFICIAL' 'OFICIAL']
#
# COLE_BILINGUE (3 valores únicos):
# ['S' 'N' '-']
#
# COLE_CARACTER (7 valores únicos):
# ['ACADÉMICO' 'NO APLICA' 'TÉCNICO/ACADÉMICO' 'TÉCNICO' '-' nan
#  'TÉCNICO/AC']
#
# COLE_AREA_UBICACION (3 valores únicos):
# ['URBANO' 'RURAL' nan]
#
# COLE_JORNADA (7 valores únicos):
# ['COMPLETA' 'SABATINA' 'MAÑANA' 'NOCHE' 'TARDE' 'UNICA' nan]
#
# ESTU_PRIVADO_LIBERTAD (3 valores únicos):
# ['N' 'S' nan]
#
# PUNT_LECTURA_CRITICA (68 valores únicos):
# [71. 75. 42. 61. 69. 49. 35. 73. 43. 62.]
# ...
#
# PUNT_MATEMATICAS (75 valores únicos):
# [65. 77. 27. 62. 75. 61. 52. 49. 53. 46.]
# ...
#
# PUNT_C_NATURALES (67 valores únicos):
# [ 69. 100.  29.  72.  67.  50.  45.  61.  38.  65.]
# ...
#
# PUNT_SOCIALES_CIUDADANAS (72 valores únicos):
# [63. 81. 36. 70. 65. 55. 73. 41. 78. 37.]
# ...
#
# PUNT_INGLES (75 valores únicos):
# [90. 86. 29. 79. 71. 58. 76. 46. 83. 45.]
# ...
#
# PUNT_GLOBAL (357 valores únicos):
# [344. 417. 166. 336. 346. 270. 214. 338. 207. 226.]
# ...

# %%
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns

plt.figure(figsize=(15, 10))
for i, col in enumerate(numeric_cols, 1):
    plt.subplot(3,3,i)
    sns.boxenplot(data=df, x=col)
    plt.title(col)

plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Análisis de valores faltantes por columna
datos_faltantes = df.isnull().sum()
porcentaje_faltas = (df.isnull().sum() / len(df)) * 100

faltantes_df = pd.DataFrame({
    'Valores faltantes': datos_faltantes,
    'Porcentaje (%)' : porcentaje_faltas
})

# Ordernar de manera descendente por %
faltantes_df = faltantes_df.sort_values(by='Porcentaje (%)', ascending=False)
faltantes_df
# Out:
#                               Valores faltantes  Porcentaje (%)
# ESTU_DEDICACIONINTERNET                    6554             4.7
# FAMI_EDUCACIONMADRE                        4472             3.2
# ESTU_TIPOREMUNERACION                      3409             2.4
# COLE_CARACTER                              3035             2.2
# FAMI_NUMLIBROS                             1861             1.3
# FAMI_PERSONASHOGAR                         1845             1.3
# FAMI_TIENEINTERNET                         1824             1.3
# FAMI_EDUCACIONPADRE                        1811             1.3
# FAMI_SITUACIONECONOMICA                    1799             1.3
# FAMI_TIENECOMPUTADOR                       1789             1.3
# FAMI_TRABAJOLABORPADRE                     1781             1.3
# FAMI_TIENECONSOLAVIDEOJUEGOS               1659             1.2
# FAMI_TRABAJOLABORMADRE                     1635             1.2
# FAMI_CUARTOSHOGAR                          1398             1.0
# ESTU_DEDICACIONLECTURADIARIA                129             0.1
# ESTU_MCPIO_RESIDE                            88             0.1
# ESTU_DEPTO_RESIDE                            88             0.1
# ESTU_HORASSEMANATRABAJA                      76             0.1
# FAMI_ESTRATOVIVIENDA                          9             0.0
# PUNT_INGLES                                   3             0.0
# ESTU_FECHANACIMIENTO                          2             0.0
# COLE_JORNADA                                  1             0.0
# PUNT_C_NATURALES                              1             0.0
# ESTU_PRIVADO_LIBERTAD                         1             0.0
# PUNT_MATEMATICAS                              1             0.0
# PUNT_SOCIALES_CIUDADANAS                      1             0.0
# PUNT_LECTURA_CRITICA                          1             0.0
# COLE_AREA_UBICACION                           1             0.0
# PUNT_GLOBAL                                   1             0.0
# COLE_BILINGUE                                 0             0.0
# COLE_NATURALEZA                               0             0.0
# COLE_GENERO                                   0             0.0
# COLE_NOMBRE_ESTABLECIMIENTO                   0             0.0
# ESTU_NACIONALIDAD                             0             0.0
# ESTU_TIENEETNIA                               0             0.0
# ESTU_PAIS_RESIDE                              0             0.0
# ESTU_CONSECUTIVO                              0             0.0
# PERIODO                                       0             0.0
# ESTU_GENERO                                   0             0.0
# ESTU_TIPODOCUMENTO                            0             0.0

# %%
# Obtener valores únicos y su frecuencia en la columna 'ESTU_TIPODOCUMENTO'
tipo_documento_counts = df['ESTU_TIPODOCUMENTO'].value_counts()

# Crear la gráfica de barras
plt.figure(figsize=(12, 4))
ax = tipo_documento_counts.plot(kind='bar', color = 'blue')

# Añadir la cantidad en cada barra
for i, v in enumerate(tipo_documento_counts):
    ax.text(i, v + 1000, str(v), ha = 'center', va='bottom', fontsize=10)

# Títulos y etiquetas
plt.title('Frecuencia de tipos de documento')
plt.xlabel('Tipo de documento')
plt.ylabel('Frecuencia')

# Mostrar la gráfica
plt.show()

# %%
# Obtener valores únicos y su frecuencia en la columna 'ESTU_NACIONALIDAD'
df['ESTU_NACIONALIDAD'].value_counts()
# Out:
# ESTU_NACIONALIDAD
# COLOMBIA                  138855
# VENEZUELA                    300
# ESTADOS UNIDOS                49
# ESPAÑA                        26
# ECUADOR                       12
# CHILE                          7
# BRASIL                         5
# ALEMANIA                       5
# FRANCIA                        5
# ARGENTINA                      4
# MÉXICO                         4
# PERÚ                           3
# COSTA RICA                     3
# ITALIA                         2
# CUBA                           2
# TERRITORIOS PALESTINOS         1
# NICARAGUA                      1
# REPÚBLICA DOMINICANA           1
# SUIZA                          1
# AUSTRIA                        1
# JAPÓN                          1
# PORTUGAL                       1
# CROACIA                        1
# PANAMÁ                         1
# EL SALVADOR                    1
# ALBANIA                        1
# TAIWAN                         1
# CANADÁ                         1
# Name: count, dtype: int64

# %%
# Obtener valores únicos y su frecuencia en la columna 'ESTU_NACIONALIDAD'
df['ESTU_GENERO'].value_counts()
# Out:
# ESTU_GENERO
# M    70308
# F    68966
# -       21
# Name: count, dtype: int64

# %%
# reemplazar valores "-"
df['ESTU_GENERO'] = df['ESTU_GENERO'].replace('-','No_informa')

# contar registros de la columna 'ESTU_GENERO'
df['ESTU_GENERO'].value_counts()
# Out:
# ESTU_GENERO
# M             70308
# F             68966
# No_informa       21
# Name: count, dtype: int64

# %%
# Cantidad de registros por el tipo de genero

# generar conteo de registros por valor único en la columna ESTU_GENERO
df_genero = df['ESTU_GENERO'].value_counts()

# establecer etiquetas y colores
etiquetas = ['F','M','No informa']
colores = ['#FFC0CB', '#6495ED', '#C0C0C0']

# crear gráfico de torta
plt.pie(df_genero, labels=etiquetas, colors=colores, autopct='%1.1f%%', startangle=90)

# agregar leyenda
plt.legend(title='Genero', loc = 'center left', bbox_to_anchor=(1.0, 0.5))

# mostrar gráfico
plt.show()

# %%
df['ESTU_FECHANACIMIENTO'].value_counts().sort_values(ascending=False)
# Out:
# ESTU_FECHANACIMIENTO
# 01/01/1900 12:00:00 AM    421
# 09/09/2002 12:00:00 AM    196
# 11/12/2002 12:00:00 AM    191
# 12/10/2002 12:00:00 AM    190
# 10/08/2002 12:00:00 AM    189
#                          ...
# 04/10/1963 12:00:00 AM      1
# 12/21/1990 12:00:00 AM      1
# 12/02/1983 12:00:00 AM      1
# 01/09/1991 12:00:00 AM      1
# 08/30/2004 12:00:00 AM      1
# Name: count, Length: 9196, dtype: int64

# %%
# Es posible que lleguemos a evidenciar un error "OutOfBoundsDatetime: Out of bounds nanosecond timestamp" cuano ejecutemos el cambio de tipo de dato, indica que en la columna
# de fechas se encuentran valores que no se pueden representar correctamente como objetos de fecha y hora de pandas.

# Para solucionar ese error, debemos identificar los valores problemáticos y limpiarlos antes de convertir la columna al formato de fecha y hora de pandas.
# Una forma de hacerlo es mediante la función "to_datetime()" de pandas, pasando el argumento "errors='coerce'". De esta forma, cualquier valor que no pueda convertirse
# correctamente será reemplazado por "NaT" (valores faltantes en pandas).

# limpiar valores problemáticos
#df_acumulado_saber_11['ESTU_FECHANACIMIENTO'] = df_acumulado_saber_11['ESTU_FECHANACIMIENTO'].str.replace('\r', '')
#df_acumulado_saber_11['ESTU_FECHANACIMIENTO'] = df_acumulado_saber_11['ESTU_FECHANACIMIENTO'].str.replace('\n', '')

# convertir columna 'ESTU_FECHANACIMIENTO' al formato de fecha y hora de pandas
df['ESTU_FECHANACIMIENTO'] = pd.to_datetime(df['ESTU_FECHANACIMIENTO'], errors='coerce')

# obtener solo el año de nacimiento
df['ANIO_NACIMIENTO'] = df['ESTU_FECHANACIMIENTO'].dt.year

# Si deseamos, tenemos la opción de eliminar o no columnas innecesarias, en este caso la columna 'ESTU_FECHANACIMIENTO' será reemplazada por 'ANIO_NACIMIENTO'
df= df.drop('ESTU_FECHANACIMIENTO', axis=1)

# mostrar resultados
df.head(3)
# Out:
# <ipython-input-28-229eac87a967>:13: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['ESTU_FECHANACIMIENTO'] = pd.to_datetime(df['ESTU_FECHANACIMIENTO'], errors='coerce')
#   ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO  PERIODO  ESTU_CONSECUTIVO  \
# 0                 CC          COLOMBIA           F    20181  SB11201810007354
# 1                 TI          COLOMBIA           M    20181  SB11201810018765
# 2                 TI          COLOMBIA           M    20181  SB11201810028523
#
#   ESTU_PAIS_RESIDE ESTU_TIENEETNIA ESTU_DEPTO_RESIDE ESTU_MCPIO_RESIDE  \
# 0         COLOMBIA              No            BOGOTA       BOGOTÁ D.C.
# 1         COLOMBIA              No             VALLE              CALI
# 2         COLOMBIA              No             VALLE              CALI
#
#   FAMI_ESTRATOVIVIENDA  ... COLE_AREA_UBICACION COLE_JORNADA  \
# 0            Estrato 6  ...              URBANO     COMPLETA
# 1            Estrato 5  ...              URBANO     COMPLETA
# 2            Estrato 1  ...               RURAL     SABATINA
#
#   ESTU_PRIVADO_LIBERTAD PUNT_LECTURA_CRITICA PUNT_MATEMATICAS  \
# 0                     N                 71.0             65.0
# 1                     N                 75.0             77.0
# 2                     N                 42.0             27.0
#
#   PUNT_C_NATURALES PUNT_SOCIALES_CIUDADANAS PUNT_INGLES PUNT_GLOBAL  \
# 0             69.0                     63.0        90.0       344.0
# 1            100.0                     81.0        86.0       417.0
# 2             29.0                     36.0        29.0       166.0
#
#   ANIO_NACIMIENTO
# 0          1999.0
# 1          2001.0
# 2          2000.0
#
# [3 rows x 40 columns]

# %%
df['ANIO_NACIMIENTO'].value_counts().sort_values(ascending=False)
# Out:
# ANIO_NACIMIENTO
# 2000.0    6865
# 2001.0    5639
# 1999.0    3448
# 1998.0     914
# 2002.0     864
#           ...
# 1955.0       2
# 1942.0       1
# 1949.0       1
# 1944.0       1
# 1953.0       1
# Name: count, Length: 62, dtype: int64

# %%
# contar registros de la columna 'ANIO_NACIMIENTO'
conteo_por_anio = df['ANIO_NACIMIENTO'].value_counts()

# filtrar años de interés, entre 2009 y 2020
filtro = (conteo_por_anio.index >= 2009) & (conteo_por_anio.index <= 2020)
conteo_por_anio_filtrado = conteo_por_anio.loc[filtro]

# Mostrar resultados
print(conteo_por_anio_filtrado)
plt.show()

print("Entre los años 2009 y 2020, hay un total de:", conteo_por_anio_filtrado.sum())
# Out:
# ANIO_NACIMIENTO
# 2017.0    21
# 2009.0     7
# 2011.0     4
# 2010.0     4
# 2012.0     2
# Name: count, dtype: int64
# Entre los años 2009 y 2020, hay un total de: 38

# %%
# Identificar los índices de los registros a eliminar
indices_eliminar = df[(df['ANIO_NACIMIENTO']
                                          >= 2009) & (df['ANIO_NACIMIENTO']<=2009)].index

# Eliminar los registros
df_resultados = df.drop(indices_eliminar)

print("Se eliminaron",conteo_por_anio_filtrado.sum(),'resgistros que pertenecen a los nacidos entre 2009 y 2020')
# Out:
# Se eliminaron 38 resgistros que pertenecen a los nacidos entre 2009 y 2020

# %%
# Conteo de registros con NaN, null o vacíos en la columna 'ANIO_NACIMIENTO'
df['ANIO_NACIMIENTO'].isna().sum()
# Out:
# 119499

# %%
# Calcular el número de registros con valores vacíos en ANIO_NACIMIENTO por grupo
vacios_por_grupo = df.groupby('ESTU_TIPODOCUMENTO')['ANIO_NACIMIENTO'].apply(lambda x: x.isna().sum())

# Ordenar de mayor a menor
vacios_grupo_sorted = vacios_por_grupo.sort_values(ascending=False)

# Imprimir cantidad de valores vacíos ordenados de mayor a menor
for grupo in vacios_grupo_sorted.index:
    print(f"Grupo: {grupo}")
    print(f"Cantidad de valores vacíos: {vacios_grupo_sorted.loc[grupo]}")
    print('-------------------------------')
# Out:
# Grupo: TI
# Cantidad de valores vacíos: 97484
# -------------------------------
# Grupo: CC
# Cantidad de valores vacíos: 20059
# -------------------------------
# Grupo: CR
# Cantidad de valores vacíos: 1390
# -------------------------------
# Grupo: CE
# Cantidad de valores vacíos: 292
# -------------------------------
# Grupo: NES
# Cantidad de valores vacíos: 189
# -------------------------------
# Grupo: PEP
# Cantidad de valores vacíos: 54
# -------------------------------
# Grupo: PE
# Cantidad de valores vacíos: 28
# -------------------------------
# Grupo: CCB
# Cantidad de valores vacíos: 2
# -------------------------------
# Grupo: PC
# Cantidad de valores vacíos: 1
# -------------------------------
# Grupo: RC
# Cantidad de valores vacíos: 0
# -------------------------------

# %%
# Calcular el número total de valores no nulos en ANIO_NACIMIENTO
total_no_nulos = df['ANIO_NACIMIENTO'].notna().sum()

# Calcular el número de registros con valores no nulos en ANIO_NACIMIENTO por grupo
no_nulos_por_grupo = df.groupby('ESTU_TIPODOCUMENTO')['ANIO_NACIMIENTO'].apply(lambda x: x.notna().sum())

# Calcular el porcentaje de cada grupo respecto al total de valores no nulos
porcentaje_por_grupo = (no_nulos_por_grupo / total_no_nulos) * 100

# Ordenar de mayor a menor
porcentaje_por_grupo_sorted = porcentaje_por_grupo.sort_values(ascending=False)

# Imprimir porcentaje de valores no nulos y cantidad por grupo
for grupo in porcentaje_por_grupo_sorted.index:
    print(f"Grupo: {grupo}")
    print(f"Cantidad de valores no nulos: {no_nulos_por_grupo.loc[grupo]}")
    print(f"Porcentajes sobre el total de valores no nulos: {porcentaje_por_grupo_sorted.loc[grupo]:.2f}%")
    print('-------------------------------')
# Out:
# Grupo: TI
# Cantidad de valores no nulos: 14259
# Porcentajes sobre el total de valores no nulos: 72.03%
# -------------------------------
# Grupo: CC
# Cantidad de valores no nulos: 5012
# Porcentajes sobre el total de valores no nulos: 25.32%
# -------------------------------
# Grupo: CR
# Cantidad de valores no nulos: 362
# Porcentajes sobre el total de valores no nulos: 1.83%
# -------------------------------
# Grupo: CE
# Cantidad de valores no nulos: 125
# Porcentajes sobre el total de valores no nulos: 0.63%
# -------------------------------
# Grupo: PE
# Cantidad de valores no nulos: 32
# Porcentajes sobre el total de valores no nulos: 0.16%
# -------------------------------
# Grupo: PC
# Cantidad de valores no nulos: 5
# Porcentajes sobre el total de valores no nulos: 0.03%
# -------------------------------
# Grupo: RC
# Cantidad de valores no nulos: 1
# Porcentajes sobre el total de valores no nulos: 0.01%
# -------------------------------
# Grupo: CCB
# Cantidad de valores no nulos: 0
# Porcentajes sobre el total de valores no nulos: 0.00%
# -------------------------------
# Grupo: NES
# Cantidad de valores no nulos: 0
# Porcentajes sobre el total de valores no nulos: 0.00%
# -------------------------------
# Grupo: PEP
# Cantidad de valores no nulos: 0
# Porcentajes sobre el total de valores no nulos: 0.00%
# -------------------------------

# %%
# Filtro para registros donde ESTU_TIPODOCUMENTO es igual a 'TI' y ANIO_NACIMIENTO es NaN
filtro_ti = (df['ESTU_TIPODOCUMENTO'] == 'TI') & (df['ANIO_NACIMIENTO'].isna())

# Número de registros a asignar
num_registro_ti = filtro_ti.sum()

# Distribución de asignación ajustada
distribucion = {
                2003: 0.5,
                2004: 0.5,
                2005: 0.3,
                2006: 0.2,
                2007: 0.2,
                2008: 0.2,
                }

# Ajustar las probabilidades para que sumen 1
total_probabilidad = sum(distribucion.values())
probabilidad_ajustadas = {key: value / total_probabilidad for key, value in distribucion.items() }

# Generar una lista de años basada en la distribución ajustada
anos_distribucion = np.random.choice(list(probabilidad_ajustadas.keys()), size=num_registro_ti, p=list(probabilidad_ajustadas.values()))

# Asignar los años a los registros filtrados
df.loc[filtro_ti, 'ANIO_NACIMIENTO'] = anos_distribucion

# Verificar los cambios
print(df.loc[filtro_ti, 'ANIO_NACIMIENTO'].value_counts())
# Out:
# ANIO_NACIMIENTO
# 2004.0    25947
# 2003.0    25534
# 2005.0    15256
# 2007.0    10330
# 2008.0    10266
# 2006.0    10151
# Name: count, dtype: int64

# %%
# Filtro para registros donde ESTU_TIPODOCUMENTO es igual a 'CC' y ANIO_NACIMIENTO es NaN
filtro_ti = (df['ESTU_TIPODOCUMENTO'] == 'CC') & (df['ANIO_NACIMIENTO'].isna())

# Número de registros a asignar
num_registro_ti = filtro_ti.sum()

# Distribución de asignación ajustada
distribucion = {
                2002: 0.5,
                2001: 0.5,
                2000: 0.3,
                1999: 0.1,
                1998: 0.1,
                1997: 0.1,
                1996: 0.1,
                1995: 0.1,
                1994: 0.1
                }

# Ajustar las probabilidades para que sumen 1
total_probabilidad = sum(distribucion.values())
probabilidad_ajustadas = {key: value / total_probabilidad for key, value in distribucion.items() }

# Generar una lista de años basada en la distribución ajustada
anos_distribucion = np.random.choice(list(probabilidad_ajustadas.keys()), size=num_registro_ti, p=list(probabilidad_ajustadas.values()))

# Asignar los años a los registros filtrados
df.loc[filtro_ti, 'ANIO_NACIMIENTO'] = anos_distribucion

# Verificar los cambios
print("Distribución de años asignados a CC")
print(df.loc[filtro_ti, 'ANIO_NACIMIENTO'].value_counts())
# Out:
# Distribución de años asignados a CC
# ANIO_NACIMIENTO
# 2002.0    5331
# 2001.0    5191
# 2000.0    3193
# 1996.0    1087
# 1999.0    1079
# 1995.0    1058
# 1998.0    1046
# 1997.0    1038
# 1994.0    1036
# Name: count, dtype: int64

# %%
# Conteo de registros con NaN, null o vacíos en la columna 'ANIO_NACIMIENTO'
df['ANIO_NACIMIENTO'].isna().sum()
# Out:
# 1956

# %%
# Calcular el número total de valores no nulos en ANIO_NACIMIENTO
total_no_nulos = df['ANIO_NACIMIENTO'].notna().sum()

# Calcular el número de registros con valores no nulos en ANIO_NACIMIENTO por grupo
no_nulos_por_grupo = df.groupby('ESTU_TIPODOCUMENTO')['ANIO_NACIMIENTO'].apply(lambda x: x.notna().sum())

# Calcular el porcentaje de cada grupo respecto al total de valores no nulos
porcentaje_por_grupo = (no_nulos_por_grupo / total_no_nulos) * 100

# Ordenar de mayor a menor
porcentaje_por_grupo_sorted = porcentaje_por_grupo.sort_values(ascending=False)

# Imprimir porcentaje de valores no nulos y cantidad por grupo
for grupo in porcentaje_por_grupo_sorted.index:
    print(f"Grupo: {grupo}")
    print(f"Cantidad de valores no nulos: {no_nulos_por_grupo.loc[grupo]}")
    print(f"Porcentajes sobre el total de valores no nulos: {porcentaje_por_grupo_sorted.loc[grupo]:.2f}%")
    print('-------------------------------')
# Out:
# Grupo: TI
# Cantidad de valores no nulos: 111743
# Porcentajes sobre el total de valores no nulos: 81.36%
# -------------------------------
# Grupo: CC
# Cantidad de valores no nulos: 25071
# Porcentajes sobre el total de valores no nulos: 18.25%
# -------------------------------
# Grupo: CR
# Cantidad de valores no nulos: 362
# Porcentajes sobre el total de valores no nulos: 0.26%
# -------------------------------
# Grupo: CE
# Cantidad de valores no nulos: 125
# Porcentajes sobre el total de valores no nulos: 0.09%
# -------------------------------
# Grupo: PE
# Cantidad de valores no nulos: 32
# Porcentajes sobre el total de valores no nulos: 0.02%
# -------------------------------
# Grupo: PC
# Cantidad de valores no nulos: 5
# Porcentajes sobre el total de valores no nulos: 0.00%
# -------------------------------
# Grupo: RC
# Cantidad de valores no nulos: 1
# Porcentajes sobre el total de valores no nulos: 0.00%
# -------------------------------
# Grupo: CCB
# Cantidad de valores no nulos: 0
# Porcentajes sobre el total de valores no nulos: 0.00%
# -------------------------------
# Grupo: NES
# Cantidad de valores no nulos: 0
# Porcentajes sobre el total de valores no nulos: 0.00%
# -------------------------------
# Grupo: PEP
# Cantidad de valores no nulos: 0
# Porcentajes sobre el total de valores no nulos: 0.00%
# -------------------------------

# %%
# Filtro para registros donde ESTU_TIPODOCUMENTO es igual a 'CC' y ANIO_NACIMIENTO es NaN
tipos_documento = ['V', 'PEP', 'NUIP', 'NIP', 'NES', 'CCB', 'RC', 'PC', 'PE', 'CE', 'CR']
filtro_ti = df['ESTU_TIPODOCUMENTO'].isin(tipos_documento)& df['ANIO_NACIMIENTO'].isna()

# Número de registros a asignar
num_registro_ti = filtro_ti.sum()

# Distribución de asignación ajustada
distribucion = {
                2006: 0.20,
                2005: 0.20,
                2004: 0.20,
                2003: 0.20,
                2002: 0.2,
                2001: 0.2,
                2000: 0.2,
                1999: 0.1,
                1998: 0.1,
                1997: 0.1,
                1996: 0.1,
                1995: 0.1,
                1994: 0.1,
                }

# Ajustar las probabilidades para que sumen 1
total_probabilidad = sum(distribucion.values())
probabilidad_ajustadas = {key: value / total_probabilidad for key, value in distribucion.items() }

# Generar una lista de años basada en la distribución ajustada
anos_distribucion = np.random.choice(list(probabilidad_ajustadas.keys()), size=num_registro_ti, p=list(probabilidad_ajustadas.values()))

# Asignar los años a los registros filtrados
df.loc[filtro_ti, 'ANIO_NACIMIENTO'] = anos_distribucion

# Verificar los cambios
print("Distribución de años asignados a CC")
print(df.loc[filtro_ti, 'ANIO_NACIMIENTO'].value_counts())
# Out:
# Distribución de años asignados a CC
# ANIO_NACIMIENTO
# 2002.0    213
# 2000.0    212
# 2003.0    193
# 2005.0    189
# 2006.0    188
# 2004.0    186
# 2001.0    180
# 1995.0    117
# 1998.0    105
# 1996.0    102
# 1997.0    101
# 1994.0     90
# 1999.0     80
# Name: count, dtype: int64

# %%
# Conteo de registros con NaN, null o vacíos en la columna 'ANIO_NACIMIENTO'
df['ANIO_NACIMIENTO'].isna().sum()
# Out:
# 0

# %%
df.sample(5)
# Out:
#        ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO  PERIODO  \
# 135277                 TI          COLOMBIA           M    20194
# 115747                 CC          COLOMBIA           M    20194
# 131905                 TI          COLOMBIA           M    20194
# 122877                 CC          COLOMBIA           F    20194
# 122428                 TI          COLOMBIA           F    20194
#
#         ESTU_CONSECUTIVO ESTU_PAIS_RESIDE ESTU_TIENEETNIA ESTU_DEPTO_RESIDE  \
# 135277  SB11201940121380         COLOMBIA              No           BOLIVAR
# 115747  SB11201940132567         COLOMBIA              No         ANTIOQUIA
# 131905  SB11201940600850         COLOMBIA              No           BOLIVAR
# 122877  SB11201940086164         COLOMBIA              No             VALLE
# 122428  SB11201940541151         COLOMBIA              No         ATLANTICO
#
#           ESTU_MCPIO_RESIDE FAMI_ESTRATOVIVIENDA  ... COLE_AREA_UBICACION  \
# 135277  CARTAGENA DE INDIAS            Estrato 3  ...              URBANO
# 115747             MEDELLÍN            Estrato 2  ...              URBANO
# 131905  CARTAGENA DE INDIAS            Estrato 2  ...              URBANO
# 122877             LA UNIÓN            Estrato 2  ...              URBANO
# 122428         BARRANQUILLA            Estrato 2  ...              URBANO
#
#        COLE_JORNADA ESTU_PRIVADO_LIBERTAD PUNT_LECTURA_CRITICA  \
# 135277     COMPLETA                     N                 70.0
# 115747        TARDE                     N                 63.0
# 131905        TARDE                     N                 40.0
# 122877        NOCHE                     N                 56.0
# 122428        UNICA                     N                 54.0
#
#        PUNT_MATEMATICAS PUNT_C_NATURALES PUNT_SOCIALES_CIUDADANAS PUNT_INGLES  \
# 135277             71.0             69.0                     64.0        59.0
# 115747             57.0             52.0                     58.0        48.0
# 131905             45.0             40.0                     37.0        44.0
# 122877             51.0             47.0                     52.0        55.0
# 122428             49.0             47.0                     34.0        49.0
#
#        PUNT_GLOBAL ANIO_NACIMIENTO
# 135277       339.0          2008.0
# 115747       284.0          2002.0
# 131905       204.0          2003.0
# 122877       259.0          2001.0
# 122428       231.0          2007.0
#
# [5 rows x 40 columns]

# %%
# generar conteo de registros por valor único en la columna ESTU_TIENEETNIA que hace referencia si pertenece o no a un tipo de etnia.

df_tenia = df['ESTU_TIENEETNIA'].value_counts().reset_index()
df_tenia.columns = ['Etenia', 'Cantidad']
df_tenia
# Out:
#   Etenia  Cantidad
# 0     No    130589
# 1     Si      8601
# 2      -       105

# %%
# generar conteo de registros por valor único en la columna ESTU_TIENEETNIA que hace referencia si pertenece o no a un tipo de etnia.
df_tenia = df['ESTU_TIENEETNIA'].value_counts().reset_index()
df_tenia.columns = ['Etnia', 'Cantidad']

# configurar etiquetas
labels = df_tenia['Etnia']
sizes = df_tenia['Cantidad']
explode = (0, 0.1, 0)

 # separar una porción del gráfico

# configurar la figura y el eje
fig, ax = plt.subplots()
fig.set_size_inches(15, 5)

# crear gráfico de dona
ax.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', startangle=90, textprops={'fontsize': 14}, wedgeprops={'width': 0.6})

# agregar etiqueta central
ax.text(0, 0, 'Etnia', horizontalalignment='center', verticalalignment='center', fontsize=10, fontweight='bold')

# mostrar resultados
plt.show()

# %%
#Los valores que estan etiquetados como "el signo menos", representan un 0.06% del total de registros, estos estan representados con el caracter "-".
# Se procederá a reemplazar en el DataFrame original ese caracter con la etiqueta de "Desconocido".

# reemplazar valores "-"
df['ESTU_TIENEETNIA'] = df['ESTU_TIENEETNIA'].replace('-','No responde')

# contar registros de la columna 'ESTU_GENERO'
df['ESTU_TIENEETNIA'].value_counts()
# Out:
# ESTU_TIENEETNIA
# No             130589
# Si               8601
# No responde       105
# Name: count, dtype: int64

# %%
# generar conteo de registros por valor único en la columna ESTU_DEPTO_RESIDE que hace referencia al departamento de residencia

df['ESTU_DEPTO_RESIDE'].value_counts()
# Out:
# ESTU_DEPTO_RESIDE
# BOGOTÁ             19389
# VALLE              15863
# ANTIOQUIA          15842
# CUNDINAMARCA        8840
# ATLANTICO           8209
# SANTANDER           5827
# BOLIVAR             5775
# BOGOTA              5403
# NARIÑO              4654
# CORDOBA             4644
# MAGDALENA           4020
# BOYACA              3946
# CAUCA               3863
# TOLIMA              3682
# NORTE SANTANDER     3567
# CESAR               3200
# HUILA               3091
# META                2854
# SUCRE               2473
# RISARALDA           2446
# CALDAS              2429
# LA GUAJIRA          1973
# CASANARE            1361
# QUINDIO             1352
# CAQUETA             1108
# PUTUMAYO             925
# CHOCO                920
# ARAUCA               788
# GUAVIARE             194
# AMAZONAS             175
# SAN ANDRES           128
# VICHADA               94
# GUAINIA               68
# VAUPES                56
# EXTRANJERO            32
# -                     16
# Name: count, dtype: int64

# %%
# Generar conteo de registros por valor único en la columna ESTU_MCPIO_RESIDE que hace referencia al municipio de residencia

unique_values = df['ESTU_MCPIO_RESIDE'].unique().tolist()
unique_values
# Out:
# ['BOGOTÁ D.C.',
#  'CALI',
#  'YUMBO',
#  'SOLEDAD',
#  'CHÍA',
#  'ENVIGADO',
#  'PALMIRA',
#  'BARRANQUILLA',
#  'EL CERRITO',
#  'PEREIRA',
#  'POPAYÁN',
#  'GUACARÍ',
#  'MEDELLÍN',
#  'GUADALAJARA DE BUGA',
#  'CARTAGENA DE INDIAS',
#  'EL PAUJÍL',
#  'LOS PATIOS',
#  'MONTERÍA',
#  'LA PLATA',
#  'PASTO',
#  'SOACHA',
#  'BELÉN DE UMBRÍA',
#  'ILES',
#  'MUTATÁ',
#  'ANCUYÁ',
#  'DUITAMA',
#  'PACHO',
#  'CAJICÁ',
#  'GUADALUPE',
#  'ARAUCA',
#  'VICTORIA',
#  'JAMUNDÍ',
#  'ZIPAQUIRÁ',
#  'MANIZALES',
#  'SAN DIEGO',
#  'FLORIDABLANCA',
#  'RESTREPO',
#  '-',
#  'DAGUA',
#  'INÍRIDA',
#  'BUCARAMANGA',
#  'PAMPLONA',
#  'PUERTO TEJADA',
#  'IBAGUÉ',
#  'CARTAGO',
#  'CANDELARIA',
#  'CAICEDONIA',
#  'APARTADÓ',
#  'VALLEDUPAR',
#  'PIEDECUESTA',
#  'TENJO',
#  'SANTA MARTA',
#  'SAN SEBASTIÁN DE MARIQUITA',
#  'MOCOA',
#  'EL CARMEN DE VIBORAL',
#  'GIRÓN',
#  'FUSAGASUGÁ',
#  'FLORIDA',
#  'FUNZA',
#  'PITALITO',
#  'CAMPO DE LA CRUZ',
#  'ARMENIA',
#  'VIJES',
#  'MAGANGUÉ',
#  'MÁLAGA',
#  'LA MESA',
#  'BELLO',
#  'LA CEJA',
#  'NEIVA',
#  'SANDONÁ',
#  'VILLAVICENCIO',
#  'TAME',
#  'LA CUMBRE',
#  'MAICAO',
#  'AGUACHICA',
#  'SANTANDER DE QUILICHAO',
#  'POTOSÍ',
#  'VILLA RICA',
#  'COTA',
#  'PUPIALES',
#  'ROLDANILLO',
#  'MALAMBO',
#  'SAN ANDRÉS',
#  'VISTAHERMOSA',
#  'SABANETA',
#  'SANTA ROSA DE CABAL',
#  'VILLA DEL ROSARIO',
#  'FACATATIVÁ',
#  'TABIO',
#  'MOSQUERA',
#  'MONTELÍBANO',
#  'FLORENCIA',
#  'ACACÍAS',
#  'GIRARDOTA',
#  'EL ZULIA',
#  'MADRID',
#  'VILLAMARÍA',
#  'PAZ DE ARIPORO',
#  'SAN GIL',
#  'TUNJA',
#  'MONTENEGRO',
#  'ALBANIA',
#  'YOPAL',
#  'BUESACO',
#  'MACHETÁ',
#  'GIRARDOT',
#  'SAN JOSÉ DEL GUAVIARE',
#  'CÚCUTA',
#  'GUAPOTÁ',
#  'CIÉNAGA',
#  'PATÍA',
#  'LA UNIÓN',
#  'LA DORADA',
#  'LA ESTRELLA',
#  'ITAGÜÍ',
#  'CABRERA',
#  'BUENAVENTURA',
#  'DOSQUEBRADAS',
#  'PAILITAS',
#  'PUERTO WILCHES',
#  'TOTORÓ',
#  'IPIALES',
#  'CHIQUINQUIRÁ',
#  'TULUÁ',
#  'MANZANARES',
#  'LOURDES',
#  'CALDAS',
#  'VITERBO',
#  'PUERRES',
#  'SOGAMOSO',
#  'SOCOTÁ',
#  'ZAPATOCA',
#  'GUACHENÉ',
#  'CUBARRAL',
#  'MACEO',
#  'PUERTO ASÍS',
#  'BOAVITA',
#  'CHINCHINÁ',
#  'MUTISCUA',
#  'CHOCONTÁ',
#  'CIRCASIA',
#  'LEJANÍAS',
#  'PIENDAMÓ - TUNÍA',
#  'ZARZAL',
#  'SARAVENA',
#  'EL SANTUARIO',
#  'ORITO',
#  'SANTA BÁRBARA',
#  'BOJACÁ',
#  'EBÉJICO',
#  'BETULIA',
#  'TAURAMENA',
#  'QUIBDÓ',
#  'PUERTO COLOMBIA',
#  'GRANADA',
#  'EL ROSAL',
#  'TIERRALTA',
#  'PALOCABILDO',
#  'RIOSUCIO',
#  'COCORNÁ',
#  'PRADERA',
#  'COGUA',
#  'CERRO DE SAN ANTONIO',
#  'LA FLORIDA',
#  'PUERTO LÓPEZ',
#  'PLANADAS',
#  'MARÍA LA BAJA',
#  'SOPÓ',
#  'CUMBAL',
#  'PALMAS DEL SOCORRO',
#  'EL COLEGIO',
#  'FREDONIA',
#  'LA CALERA',
#  'OCAÑA',
#  'SAMANÁ',
#  'IMUÉS',
#  'SAN PELAYO',
#  'DONMATÍAS',
#  'GUAMO',
#  'GUADUAS',
#  'SAN LUIS',
#  'SOCORRO',
#  'CALIMA',
#  'BARBOSA',
#  'RETIRO',
#  'SIBATÉ',
#  'ANDALUCÍA',
#  'YOTOCO',
#  'AGUAZUL',
#  'ARMERO',
#  'GINEBRA',
#  'BUGALAGRANDE',
#  'TOCANCIPÁ',
#  'SAN BERNARDO',
#  'CABUYARO',
#  'CHALÁN',
#  'EXTRANJERO',
#  'LA VICTORIA',
#  'GUARNE',
#  'MARINILLA',
#  'NARIÑO',
#  'SAN VICENTE FERRER',
#  'SUESCA',
#  'JUAN DE ACOSTA',
#  'FONSECA',
#  'PONEDERA',
#  'ANAPOIMA',
#  'SUAZA',
#  'RIONEGRO',
#  'SABANAS DE SAN ÁNGEL',
#  'ALTAMIRA',
#  'ITUANGO',
#  'HATONUEVO',
#  'SINCELEJO',
#  'ACEVEDO',
#  'VILLANUEVA',
#  'VILLA DE SAN DIEGO DE UBATÉ',
#  'SUSACÓN',
#  'ALMAGUER',
#  'BOYACÁ',
#  'SAN FRANCISCO',
#  'BOLÍVAR',
#  'COPACABANA',
#  'ALDANA',
#  'BALBOA',
#  'SANTA ROSA DE OSOS',
#  'TANGUA',
#  'COYAIMA',
#  'REMEDIOS',
#  'PORE',
#  'GUACHETÁ',
#  'MURINDÓ',
#  'ARBELÁEZ',
#  'SAN PEDRO DE LOS MILAGROS',
#  'CAJIBÍO',
#  'VERSALLES',
#  'GUACHUCAL',
#  'SAN PEDRO',
#  'TOLEDO',
#  'SUBACHOQUE',
#  'RICAURTE',
#  'CONCORDIA',
#  'LEBRIJA',
#  'TRINIDAD',
#  'RIVERA',
#  'FILANDIA',
#  'MESETAS',
#  'PUEBLO RICO',
#  'ANSERMA',
#  'FALAN',
#  'YARUMAL',
#  'GARZÓN',
#  'SANTO DOMINGO',
#  'COLOMBIA',
#  'LA VIRGINIA',
#  'OLAYA HERRERA',
#  'EL CASTILLO',
#  'CALARCÁ',
#  'SANTA ANA',
#  'MONTECRISTO',
#  'EL PASO',
#  'GALAPA',
#  'BARANOA',
#  'CORINTO',
#  'VALENCIA',
#  'LORICA',
#  'SABANALARGA',
#  'ARJONA',
#  'PUERTO GAITÁN',
#  'SAN ONOFRE',
#  'EL CARMEN DE BOLÍVAR',
#  'TOLÚ VIEJO',
#  'RIOFRÍO',
#  'SAMPUÉS',
#  'LA APARTADA',
#  'CIÉNAGA DE ORO',
#  'BARRANCAS',
#  'SAHAGÚN',
#  'NOCAIMA',
#  'BARRANCABERMEJA',
#  'TURBACO',
#  'CERETÉ',
#  'GUAPÍ',
#  'SAN MARCOS',
#  'MIRANDA',
#  'EL RETÉN',
#  'AGUSTÍN CODAZZI',
#  'HATILLO DE LOBA',
#  'ARIGUANÍ',
#  'SAN SEBASTIÁN DE BUENAVISTA',
#  'PUEBLO NUEVO',
#  'RIOHACHA',
#  'SAN ANTERO',
#  'AYAPEL',
#  'ACHÍ',
#  'PELAYA',
#  'SAN JUAN DE URABÁ',
#  'CURUMANÍ',
#  'SUAITA',
#  'URIBIA',
#  'BOSCONIA',
#  'PLANETA RICA',
#  'CALDONO',
#  'FUNDACIÓN',
#  'PUERTO LIBERTADOR',
#  'PINILLOS',
#  'MORALES',
#  'UNGUÍA',
#  'COTORRA',
#  'LOS PALMITOS',
#  'ALTO BAUDÓ',
#  'ORTEGA',
#  'GALERAS',
#  'MAHATES',
#  'SOPETRÁN',
#  'SANTA MARÍA',
#  'GUARANDA',
#  'NUEVA GRANADA',
#  'SANTO TOMÁS',
#  'MITÚ',
#  'CHIGORODÓ',
#  'SANTA ROSA',
#  'CAMPOALEGRE',
#  'ALTOS DEL ROSARIO',
#  'SALAMINA',
#  'TIBÚ',
#  'MAJAGUAL',
#  'EL BAGRE',
#  'TORIBÍO',
#  'SAN JUAN NEPOMUCENO',
#  'SANTA ROSALÍA',
#  'PUERTO RICO',
#  'PROVIDENCIA',
#  'TELLO',
#  'SABANAGRANDE',
#  'MARGARITA',
#  'LA ESPERANZA',
#  'ROVIRA',
#  'SAN ANDRÉS DE TUMACO',
#  'PLATO',
#  'FUNES',
#  'SUCRE',
#  'GIGANTE',
#  'PUERTO SANTANDER',
#  'PUENTE NACIONAL',
#  'CUMARIBO',
#  'SAN CRISTÓBAL',
#  'MANAURE BALCÓN DEL CESAR',
#  'PEQUE',
#  'DISTRACCIÓN',
#  'EL PIÑÓN',
#  'LA VEGA',
#  'MOMPÓS',
#  'BARRANCO DE LOBA',
#  'ALGARROBO',
#  'GÁMBITA',
#  'EL ROBLE',
#  'VALLE DE SAN JOSÉ',
#  'TENERIFE',
#  'MOMIL',
#  'SILVIA',
#  'ALBÁN',
#  'YOLOMBÓ',
#  'CÓRDOBA',
#  'LA MONTAÑITA',
#  'SAN VICENTE DEL CAGUÁN',
#  'LIBORINA',
#  'CURILLO',
#  'TURBO',
#  'ENTRERRÍOS',
#  'SAN MARTÍN DE LOBA',
#  'BUENAVISTA',
#  'ANSERMANUEVO',
#  'FUENTEDEORO',
#  'SAN PABLO DE BORBUR',
#  'SAN ANDRÉS DE SOTAVENTO',
#  'ARACATACA',
#  'DIBULLA',
#  'ZONA BANANERA',
#  'TORO',
#  'PIOJÓ',
#  'EL BANCO',
#  nan,
#  'EL PEÑÓN',
#  'SAN JERÓNIMO',
#  'CERRITO',
#  'CAUCASIA',
#  'FRONTINO',
#  'SUPÍA',
#  'QUIMBAYA',
#  'ASTREA',
#  'TALAIGUA NUEVO',
#  'MANATÍ',
#  'JURADÓ',
#  'TUBARÁ',
#  'OVEJAS',
#  'LURUACO',
#  'MANAURE',
#  'SAN JUAN DEL CESAR',
#  'PURIFICACIÓN',
#  'POLICARPA',
#  'CHINÚ',
#  'LA GLORIA',
#  'BECERRIL',
#  'GUALMATÁN',
#  'PUEBLOVIEJO',
#  'CHIMICHAGUA',
#  'LETICIA',
#  'CALAMAR',
#  'TURBANÁ',
#  'SOLITA',
#  'CUASPÚD',
#  'FORTUL',
#  'EL DONCELLO',
#  'LA TOLA',
#  'BAJO BAUDÓ',
#  'CICUCO',
#  'CARTAGENA DEL CHAIRÁ',
#  'PUERTO ESCONDIDO',
#  'COVEÑAS',
#  'SAN PEDRO DE URABÁ',
#  'TOGÜÍ',
#  'ARBOLETES',
#  'BOJAYÁ',
#  'SAN BERNARDO DEL VIENTO',
#  'SAN MARTÍN',
#  'PIAMONTE',
#  'TÁMARA',
#  'HATO COROZAL',
#  'MAGÜÍ',
#  'PUERTO LEGUÍZAMO',
#  'SAN SEBASTIÁN',
#  'PINCHOTE',
#  'CHIRIGUANÁ',
#  'GUAMAL',
#  'VIGÍA DEL FUERTE',
#  'NATAGAIMA',
#  'PUERTO NARIÑO',
#  'LA PRIMAVERA',
#  'CUCUTILLA',
#  'PIVIJAY',
#  'SANTA FÉ DE ANTIOQUIA',
#  'CHAPARRAL',
#  'ZARAGOZA',
#  'ESPINAL',
#  'BARRANCO MINAS',
#  'ATRATO',
#  'LA JAGUA DE IBIRICO',
#  'NECOCLÍ',
#  'LOS CÓRDOBAS',
#  'CONVENCIÓN',
#  'SILVANIA',
#  'TUTA',
#  'SANTA ROSA DE VITERBO',
#  'GUAITARILLA',
#  'MALLAMA',
#  'JARDÍN',
#  'ABRIAQUÍ',
#  'QUINCHÍA',
#  'UBALÁ',
#  'ZAPAYÁN',
#  'CALOTO',
#  'SAN BENITO ABAD',
#  'TAMALAMEQUE',
#  'MOÑITOS',
#  'ISNOS',
#  'ALGECIRAS',
#  'PALMITO',
#  'CUNDAY',
#  'PUERTO BERRÍO',
#  'GRAMALOTE',
#  'TEORAMA',
#  'NOROSÍ',
#  'BARBACOAS',
#  'AQUITANIA',
#  'PURÍSIMA DE LA CONCEPCIÓN',
#  'SIBUNDOY',
#  'TAMINANGO',
#  'INZÁ',
#  'GACHANCIPÁ',
#  'TARAZÁ',
#  'SATIVANORTE',
#  'BERBEO',
#  'LA PAZ',
#  'CHINÁCOTA',
#  'LA PLAYA',
#  'CUCUNUBÁ',
#  'GALÁN',
#  'TARQUI',
#  'PAYA',
#  'EL PEÑOL',
#  'TUCHÍN',
#  'VÉLEZ',
#  'SAN ESTANISLAO',
#  'SANTANA',
#  'YACUANQUER',
#  'AGUADAS',
#  'SAN PABLO',
#  'PAICOL',
#  'PÁEZ',
#  'LA CRUZ',
#  'LÉRIDA',
#  'TIMBÍO',
#  'ROSAS',
#  'JAMBALÓ',
#  'MONGUÍ',
#  'ABEJORRAL',
#  'MOTAVITA',
#  'SANTA HELENA DEL OPÓN',
#  'CHITA',
#  'LOS ANDES',
#  'SANTIAGO DE TOLÚ',
#  'PITAL',
#  'PUERTO GUZMÁN',
#  'CÁQUEZA',
#  'SAN VICENTE DE CHUCURÍ',
#  'LA UVITA',
#  'CÁCERES',
#  'SAN LORENZO',
#  'MORROA',
#  'VALLE DEL GUAMUEZ',
#  'SABOYÁ',
#  'PEÑOL',
#  'SANTA LUCÍA',
#  'SITIONUEVO',
#  'SAN JUAN DE BETULIA',
#  'SUAN',
#  'REPELÓN',
#  'ÁBREGO',
#  'ULLOA',
#  'PURACÉ',
#  'TÚQUERRES',
#  'CHOACHÍ',
#  'RONCESVALLES',
#  'ISTMINA',
#  'MOLAGAVITA',
#  'BELMIRA',
#  'EL DOVIO',
#  'GARAGOA',
#  'SOTARA',
#  'CISNEROS',
#  'CONDOTO',
#  'QUÍPAMA',
#  'CAIMITO',
#  'EL CARMEN',
#  'VIOTÁ',
#  'CARACOLÍ',
#  'ICONONZO',
#  'EL TAMBO',
#  'OLAYA',
#  'SABANA DE TORRES',
#  'SAN ALBERTO',
#  'EL TARRA',
#  'MARQUETALIA',
#  'YACOPÍ',
#  'BUENOS AIRES',
#  'UNE',
#  'PARATEBUENO',
#  'HONDA',
#  'SAN JOSÉ DE PARE',
#  'TRUJILLO',
#  'ÚMBITA',
#  'NUEVO COLÓN',
#  'SIACHOQUE',
#  'CASTILLA LA NUEVA',
#  'VEGACHÍ',
#  'ARAUQUITA',
#  'GONZÁLEZ',
#  'SAN AGUSTÍN',
#  'NOBSA',
#  'ROBERTO PAYÁN',
#  'SAN JACINTO',
#  'PAIPA',
#  'POLONUEVO',
#  'VENTAQUEMADA',
#  'SARDINATA',
#  'CHARALÁ',
#  'LÍBANO',
#  'TOCA',
#  'ÍQUIRA',
#  'VILLAVIEJA',
#  'SAN ANDRÉS DE CUERQUÍA',
#  'CRAVO NORTE',
#  'CANALETE',
#  'YONDÓ',
#  'COROZAL',
#  'GACHALÁ',
#  'LOS SANTOS',
#  'SAN CARLOS DE GUAROA',
#  'MOGOTES',
#  'OSPINA',
#  'MELGAR',
#  'SAN PEDRO DE CARTAGO',
#  'CHITAGÁ',
#  'TIMBIQUÍ',
#  'SAMACÁ',
#  'RAMIRIQUÍ',
#  'PUERTO BOYACÁ',
#  'PUEBLO BELLO',
#  'VILLA CARO',
#  'ATACO',
#  'SALAZAR',
#  'CUMBITARA',
#  'SAN CARLOS',
#  'SESQUILÉ',
#  'UBAQUE',
#  'SORACÁ',
#  'VILLARRICA',
#  'SANTA ROSA DEL SUR',
#  'OTANCHE',
#  'CIMITARRA',
#  'COROMORO',
#  'PANQUEBA',
#  'TOPAIPÍ',
#  'PUEBLORRICO',
#  'SIMIJACA',
#  'TIQUISIO',
#  'MURILLO',
#  'FÚQUENE',
#  'COLÓN',
#  'USIACURÍ',
#  'FLANDES',
#  'CHISCAS',
#  'GAMARRA',
#  'ANDES',
#  'ANORÍ',
#  'CURITÍ',
#  'MILÁN',
#  'PÁRAMO',
#  'TIBIRITA',
#  'PUERTO TRIUNFO',
#  'NECHÍ',
#  'EL TABLÓN DE GÓMEZ',
#  'TENZA',
#  'SAN ZENÓN',
#  'PAUNA',
#  'EL COPEY',
#  'OCAMONTE',
#  'SALADOBLANCO',
#  'CÁCHIRA',
#  'PAJARITO',
#  'SAN ANTONIO',
#  'EL PLAYÓN',
#  'SAN MIGUEL',
#  'PIEDRAS',
#  'SILOS',
#  'RÍO IRÓ',
#  'SAN CALIXTO',
#  'COLOSÓ',
#  'SUPATÁ',
#  'GACHANTIVÁ',
#  'FIRAVITOBA',
#  'LA ARGENTINA',
#  'SEGOVIA',
#  'NORCASIA',
#  'LENGUAZAQUE',
#  'EL COCUY',
#  'LANDÁZURI',
#  'BARICHARA',
#  'HOBO',
#  'PUERTO CONCORDIA',
#  'ARATOCA',
#  'QUEBRADANEGRA',
#  'MANÍ',
#  'SAN CAYETANO',
#  'MONTEBELLO',
#  'SAN ROQUE',
#  'SAN JOAQUÍN',
#  'CHIVOLO',
#  'SÁCHICA',
#  'VILLETA',
#  'SANTA BÁRBARA DE PINTO',
#  'MONIQUIRÁ',
#  'TIBANÁ',
#  'PUERTO CAICEDO',
#  'QUIPILE',
#  'PEDRAZA',
#  'PALERMO',
#  'MISTRATÓ',
#  'VILLA DE LEYVA',
#  'MIRAFLORES',
#  'PASCA',
#  'LA BELLEZA',
#  'REMOLINO',
#  'RAGONVALIA',
#  'SONSÓN',
#  'NEMOCÓN',
#  'RECETOR',
#  'AGUA DE DIOS',
#  'TIMANÁ',
#  'ARBOLEDA',
#  'SUSA',
#  'LA SIERRA',
#  'ARROYOHONDO',
#  'COVARACHÍA',
#  'EL CAIRO',
#  'JENESANO',
#  'PUERTO CARREÑO',
#  'GUAYATÁ',
#  'RÁQUIRA',
#  'EL ESPINO',
#  'TASCO',
#  'CAJAMARCA',
#  'CHIPAQUE',
#  'VILLAPINZÓN',
#  'TIPACOQUE',
#  'TURMEQUÉ',
#  'CAÑASGORDAS',
#  'BELALCÁZAR',
#  'GUÁTICA',
#  'LA PEDRERA',
#  'FOSCA',
#  'CHIPATÁ',
#  'CARCASÍ',
#  'SAN JOSÉ DEL FRAGUA',
#  'NUNCHÍA',
#  'HELICONIA',
#  'EL CARMEN DE ATRATO',
#  'ANZÁ',
#  'PAZ DE RÍO',
#  'TOCAIMA',
#  'BETANIA',
#  'MORELIA',
#  'FRESNO',
#  'VILLAGARZÓN',
#  'CLEMENCIA',
#  'JERICÓ',
#  'TADÓ',
#  'OBANDO',
#  'SAN LUIS DE SINCÉ',
#  'LLORÓ',
#  'VALPARAÍSO',
#  'RÍO VIEJO',
#  'ELÍAS',
#  'ARGELIA',
#  'SAN ANTONIO DEL TEQUENDAMA',
#  'GAMA',
#  'RÍO DE ORO',
#  'VILLAGÓMEZ',
#  'LA TEBAIDA',
#  'GUAYABETAL',
#  'MACANAL',
#  'URRAO',
#  'AIPE',
#  'AGRADO',
#  'BAGADÓ',
#  'PALMAR DE VARELA',
#  'BAHÍA SOLANO',
#  'SAN RAFAEL',
#  'ALCALÁ',
#  'VIRACACHÁ',
#  'LA JAGUA DEL PILAR',
#  'EL ROSARIO',
#  'CARMEN DE CARUPA',
#  'CAPITANEJO',
#  'CIÉNEGA',
#  'SIMACOTA',
#  'GÉNOVA',
#  'CHINAVITA',
#  'PRADO',
#  'TENA',
#  'RISARALDA',
#  'MEDIO BAUDÓ',
#  'TARAPACÁ',
#  'OROCUÉ',
#  'SALDAÑA',
#  'FÓMEQUE',
#  'AMALFI',
#  'SANTIAGO',
#  'SAMANIEGO',
#  'PIJAO',
#  'GUACA',
#  'GUAYABAL DE SÍQUIMA',
#  'LABATECA',
#  'APÍA',
#  'SANTA CATALINA',
#  'CAROLINA',
#  'DABEIBA',
#  'SAN JACINTO DEL CAUCA',
#  'SAN JOSÉ DE URÉ',
#  'SAN JOSÉ DE MIRANDA',
#  'EL LITORAL DEL SAN JUAN',
#  'BOCHALEMA',
#  'ENCISO',
#  'SAN JUAN DE RIOSECO',
#  'URUMITA',
#  'ANGOSTURA',
#  'FRANCISCO PIZARRO',
#  'RÍO QUITO',
#  'MUZO',
#  'MATANZA',
#  'EL RETORNO',
#  'DOLORES',
#  'EL MOLINO',
#  'ANZOÁTEGUI',
#  'SOPLAVIENTO',
#  'CUBARÁ',
#  'VENECIA',
#  'CHACHAGÜÍ',
#  'LA LLANADA',
#  'VERGARA',
#  'SEVILLA',
#  'GUASCA',
#  'SIMITÍ',
#  'PALESTINA',
#  'CUMARAL',
#  'EL ÁGUILA',
#  'CASABIANCA',
#  'LINARES',
#  'CAREPA',
#  'NEIRA',
#  'MONTERREY',
#  'RIOBLANCO',
#  'PÁCORA',
#  'CAICEDO',
#  'ALVARADO',
#  'CIUDAD BOLÍVAR',
#  'CÓMBITA',
#  'ANOLAIMA',
#  'MEDINA',
#  'MARMATO',
#  'GÜEPSA',
#  'SASAIMA',
#  'GÓMEZ PLATA',
#  'ALEJANDRÍA',
#  'SUÁREZ',
#  'TARSO',
#  'AMAGÁ',
#  'PADILLA',
#  'YALÍ',
#  'APULO',
#  'CAMPAMENTO',
#  'YAGUARÁ',
#  'PENSILVANIA',
#  'FILADELFIA',
#  'MARULANDA',
#  'EL CARMEN DE CHUCURÍ',
#  'COELLO',
#  'ARANZAZU',
#  'COPER',
#  'LA MACARENA',
#  'PUERTO NARE',
#  'SALGAR',
#  'SOATÁ',
#  'PISBA',
#  'CHIMÁ',
#  'OIBA',
#  'MARSELLA',
#  'GIRALDO',
#  'LA MERCED',
#  'TERUEL',
#  'ALMEIDA',
#  'SAN FERNANDO',
#  'TÁMESIS',
#  'SANTUARIO',
#  'BITUIMA',
#  'URAMITA',
#  'HISPANIA',
#  'ARENAL',
#  'PUERTO PARRA',
#  'LEIVA',
#  'SAN MIGUEL DE SEMA',
#  'CÉRTEGUI',
#  'GUATEQUE',
#  'PIJIÑO DEL CARMEN',
#  'LA CHORRERA',
#  'CONSACÁ',
#  'PUERTO LLERAS',
#  'ZAMBRANO',
#  'LA PEÑA',
#  'SALENTO',
#  'VALDIVIA',
#  'GUATAPÉ',
#  'CONCEPCIÓN',
#  'CAPARRAPÍ',
#  'BRICEÑO',
#  'TONA',
#  'OPORAPA',
#  'TÓPAGA',
#  'MAPIRIPÁN',
#  'LA CELIA',
#  'MONGUA',
#  'NUQUÍ',
#  'ARBOLEDAS',
#  'SOTAQUIRÁ',
#  'BELÉN DE LOS ANDAQUÍES',
#  'SAN LUIS DE PALENQUE',
#  'NÓVITA',
#  'SAN FELIPE',
#  'GACHETÁ',
#  'PUERTO SALGAR',
#  'MEDIO SAN JUAN',
#  'GÁMEZA',
#  'VALLE DE SAN JUAN',
#  'NILO',
#  'TIBASOSA',
#  'CACHIPAY',
#  'QUETAME',
#  'EL CANTÓN DEL SAN PABLO',
#  'SAN MATEO',
#  'LA SALINA',
#  'ÚTICA',
#  'CONTRATACIÓN',
#  'CUCAITA',
#  'PALMAR',
#  'CHÍQUIZA',
#  'BURITICÁ',
#  'EL GUAMO',
#  'NÁTAGA',
#  'PESCA',
#  'TITIRIBÍ',
#  'VENADILLO',
#  'SAPUYES',
#  'LA PALMA',
#  'NIMAIMA',
#  'SAN JOSÉ',
#  'TINJACÁ',
#  'SANTACRUZ',
#  'SAN JOSÉ DE LA MONTAÑA',
#  'SAN BENITO',
#  'CARURÚ',
#  'EL CHARCO',
#  'GUATAVITA',
#  'ARCABUCO',
#  'ZETAQUIRA',
#  'GUATAQUÍ',
#  'MERCADERES',
#  'SAN JUAN DE ARAMA',
#  'SUTATAUSA',
#  'SOLANO',
#  'LA PINTADA',
#  'TESALIA',
#  'BELÉN',
#  'ZIPACÓN',
#  'HERVEO',
#  'CHITARAQUE',
#  'CARMEN DE APICALÁ',
#  'AGUADA',
#  'TAUSA',
#  'UNIÓN PANAMERICANA',
#  'SAN LUIS DE GACENO',
#  'SOCHA',
#  'TARAIRA',
#  'GUACAMAYAS',
#  'CHIVATÁ',
#  'SURATÁ',
#  'EL DORADO',
#  'ANGELÓPOLIS',
#  'AMBALEMA',
#  'CARMEN DEL DARIÉN',
#  'VIANÍ',
#  'SORA',
#  'TUTAZÁ',
#  'DURANIA',
#  'CONTADERO',
#  'EL CALVARIO',
#  'PUERTO RONDÓN',
#  'BARRANCA DE UPÍA',
#  'MANTA',
#  'LÓPEZ DE MICAY',
#  'FLORIÁN',
#  'MIRITÍ - PARANÁ',
#  'CERINZA',
#  'CONFINES',
#  'JERUSALÉN',
#  'GUTIÉRREZ',
#  'GÜICÁN DE LA SIERRA',
#  'PAMPLONITA',
#  'CHAGUANÍ',
#  'MARIPÍ',
#  'HACARÍ',
#  'PULÍ',
#  'SAN JUANITO',
#  'SAN JOSÉ DEL PALMAR',
#  'SANTA SOFÍA',
#  'SUTAMARCHÁN',
#  'JORDÁN',
#  'JUNÍN',
#  'CARAMANTA',
#  'CHIMA',
#  'OICATÁ',
#  'VILLAHERMOSA',
#  'LA CAPILLA',
#  'TIBACUY',
#  'MACARAVITA',
#  'GUAVATÁ',
#  'PANDI',
#  'CHIVOR',
#  'TUNUNGUÁ',
#  'ACANDÍ',
#  'BARAYA',
#  'CÁCOTA',
#  'SAN EDUARDO',
#  'EL GUACAMAYO',
#  'FLORESTA',
#  'CHÁMEZA',
#  'CEPITÁ',
#  'SUTATENZA',
#  'BUSBANZÁ',
#  'PAIME',
#  ...]

# %%
# generar conteo de registros por valor único en la columna FAMI_ESTRATOVIVIENDAA que hace referencia al estrato de la vivienda de los estudiantes.

df['FAMI_ESTRATOVIVIENDA'].value_counts()
# Out:
# FAMI_ESTRATOVIVIENDA
# Estrato 2      45150
# Estrato 1      36377
# Estrato 3      28535
# Estrato 4       8736
# -               7419
# Sin Estrato     5233
# Estrato 5       4524
# Estrato 6       3312
# Name: count, dtype: int64

# %%
# Reemplazar valores de registros para el ahorro de recurso compuracional

# Crear un diccionario
replace_dict = {
                '-'             : 'No sabe',
                'Estrato 1'     : '1',
                'Estrato 2'     : '2',
                'Estrato 3'     : '3',
                'Estrato 4'     : '4',
                'Estrato 5'     : '5',
                'Estrato 6'     : '6',
                'Sin Estrato'   : 'No sabe'
}

# Implementar la función .replace
df['FAMI_ESTRATOVIVIENDA'].replace(replace_dict, inplace=True)
df['FAMI_ESTRATOVIVIENDA'].value_counts()
# Out:
# <ipython-input-48-7e9b9aea2330>:16: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['FAMI_ESTRATOVIVIENDA'].replace(replace_dict, inplace=True)
# FAMI_ESTRATOVIVIENDA
# 2          45150
# 1          36377
# 3          28535
# No sabe    12652
# 4           8736
# 5           4524
# 6           3312
# Name: count, dtype: int64

# %%
df['FAMI_PERSONASHOGAR'].value_counts()
# Out:
# FAMI_PERSONASHOGAR
# 3 a 4            67739
# 5 a 6            41910
# 1 a 2            10744
# 7 a 8            10544
# 9 o más           4161
# -                 1639
# Sin Respuesta      713
# Name: count, dtype: int64

# %%
df['FAMI_CUARTOSHOGAR'].value_counts()
# Out:
# FAMI_CUARTOSHOGAR
# Tres             53686
# Dos              46475
# Cuatro           18953
# Uno               6845
# Cinco             5886
# Seis o mas        3118
# -                 2323
# Sin respuesta      611
# Name: count, dtype: int64

# %%
# Reemplazar valores de registros para el ahorro de recurso compuracional

# Crear un diccionario
replace_dict = {
                    'Uno'               : '1',
                    'Dos'               : '2',
                    'Tres'              : '3',
                    'Cuatro'            : '4',
                    'Cinco'             : '5',
                    'Seis o mas'        : '6',
                    '-'                 : 'No responde',
                    'Sin respuesta'     : 'No responde'
                }

# Implementar la función .replace
df['FAMI_CUARTOSHOGAR'].replace(replace_dict, inplace=True)
df['FAMI_CUARTOSHOGAR'].value_counts()
# Out:
# <ipython-input-51-bd2ad9ab4b6e>:16: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['FAMI_CUARTOSHOGAR'].replace(replace_dict, inplace=True)
# FAMI_CUARTOSHOGAR
# 3              53686
# 2              46475
# 4              18953
# 1               6845
# 5               5886
# 6               3118
# No responde     2934
# Name: count, dtype: int64

# %%
df['FAMI_NUMLIBROS'].value_counts()
# Out:
# FAMI_NUMLIBROS
# 0 A 10 LIBROS        49295
# 11 A 25 LIBROS       38182
# 26 A 100 LIBROS      28932
# MÁS DE 100 LIBROS    11788
# -                     9237
# Name: count, dtype: int64

# %%
# Reemplazar valores de registros para el ahorro de recurso compuracional

# Crear un diccionario
replace_dict = {
                    '0 A 10 LIBROS'     : '0-10',
                    '11 A 25 LIBROS'    : '11-25',
                    '26 A 100 LIBROS'   : '26-100',
                    'MÁS DE 100 LIBROS' : '>100',
                    '-'                 : 'No sabe'
                }

# Implementar la función .replace
df['FAMI_NUMLIBROS'].replace(replace_dict, inplace=True)
df['FAMI_NUMLIBROS'].value_counts()
# Out:
# <ipython-input-53-1c1cee280a3d>:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['FAMI_NUMLIBROS'].replace(replace_dict, inplace=True)
# FAMI_NUMLIBROS
# 0-10       49295
# 11-25      38182
# 26-100     28932
# >100       11788
# No sabe     9237
# Name: count, dtype: int64

# %%
df['ESTU_DEDICACIONLECTURADIARIA'].value_counts()
# Out:
# ESTU_DEDICACIONLECTURADIARIA
# 30 minutos o menos            50169
# Entre 30 y 60 minutos         36508
# No leo por entretenimiento    25104
# Entre 1 y 2 horas             14152
# -                              8105
# Más de 2 horas                 5128
# Name: count, dtype: int64

# %%
# Reemplazar valores de registros para el ahorro de recurso compuracional

# Crear un diccionario
replace_dict = {
                    '30 minutos o menos'            : '<30',
                    'Entre 30 y 60 minutos'         : '30-60',
                    'Entre 1 y 2 horas'             : '1h-2h',
                    'Más de 2 horas'                : '>2h',
                    'No leo por entretenimiento'    : 'No lee',
                    '-'                             : 'No responde'
                }

# Implementar la función .replace
df['ESTU_DEDICACIONLECTURADIARIA'].replace(replace_dict, inplace=True)
df['ESTU_DEDICACIONLECTURADIARIA'].value_counts()
# Out:
# <ipython-input-55-183c337d97fe>:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['ESTU_DEDICACIONLECTURADIARIA'].replace(replace_dict, inplace=True)
# ESTU_DEDICACIONLECTURADIARIA
# <30            50169
# 30-60          36508
# No lee         25104
# 1h-2h          14152
# No responde     8105
# >2h             5128
# Name: count, dtype: int64

# %%
df['ESTU_DEDICACIONINTERNET'].value_counts()
# Out:
# ESTU_DEDICACIONINTERNET
# Entre 1 y 3 horas        41270
# Entre 30 y 60 minutos    33201
# Más de 3 horas           27507
# 30 minutos o menos       21646
# No Navega Internet        7141
# -                         1976
# Name: count, dtype: int64

# %%
# Reemplazar valores de registros para el ahorro de recurso compuracional

# Crear un diccionario
replace_dict = {
                    '30 minutos o menos'            : '<30',
                    'Entre 30 y 60 minutos'         : '30-60',
                    'Entre 1 y 3 horas'             : '1h-3h',
                    'Más de 3 horas'                : '>3h',
                    'No Navega Internet'            : 'No navega',
                    '-'                             : 'No responde'
                }

# Implementar la función .replace
df['ESTU_DEDICACIONINTERNET'].replace(replace_dict, inplace=True)
df['ESTU_DEDICACIONINTERNET'].value_counts()
# Out:
# <ipython-input-57-b9c6949c03bd>:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['ESTU_DEDICACIONINTERNET'].replace(replace_dict, inplace=True)
# ESTU_DEDICACIONINTERNET
# 1h-3h          41270
# 30-60          33201
# >3h            27507
# <30            21646
# No navega       7141
# No responde     1976
# Name: count, dtype: int64

# %%
df['ESTU_HORASSEMANATRABAJA'].value_counts()
# Out:
# ESTU_HORASSEMANATRABAJA
# 0                      91391
# Menos de 10 horas      23709
# Entre 11 y 20 horas    10400
# Más de 30 horas         5536
# -                       4204
# Entre 21 y 30 horas     3979
# Name: count, dtype: int64

# %%
# Reemplazar valores de registros para el ahorro de recurso compuracional

# Crear un diccionario
replace_dict = {
                    '0'                     : '0',
                    'Menos de 10 horas'     : '<10',
                    'Entre 11 y 20 horas'   : '11-20',
                    'Entre 21 y 30 horas'   : '21-30',
                    'Más de 30 horas'       : '>30',
                    '-'                     : 'No responde'
                }

# Implementar la función .replace
df['ESTU_HORASSEMANATRABAJA'].replace(replace_dict, inplace=True)
df['ESTU_HORASSEMANATRABAJA'].value_counts()
# Out:
# <ipython-input-59-da1039a59bb8>:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['ESTU_HORASSEMANATRABAJA'].replace(replace_dict, inplace=True)
# ESTU_HORASSEMANATRABAJA
# 0              91391
# <10            23709
# 11-20          10400
# >30             5536
# No responde     4204
# 21-30           3979
# Name: count, dtype: int64

# %%
df['ESTU_TIPOREMUNERACION'].value_counts()
# Out:
# ESTU_TIPOREMUNERACION
# No                           96389
# Si, en efectivo              34244
# Si, en especie                2131
# Si, en efectivo y especie     1872
# -                             1250
# Name: count, dtype: int64

# %%
# Reemplazar valores de registros para el ahorro de recurso compuracional

# Crear un diccionario
replace_dict = {
                    '-' : 'Prefiero no responder'
                }

# Implementar la función .replace
df['ESTU_TIPOREMUNERACION'].replace(replace_dict, inplace=True)
df['ESTU_TIPOREMUNERACION'].value_counts()
# Out:
# <ipython-input-61-dc52d6551c14>:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['ESTU_TIPOREMUNERACION'].replace(replace_dict, inplace=True)
# ESTU_TIPOREMUNERACION
# No                           96389
# Si, en efectivo              34244
# Si, en especie                2131
# Si, en efectivo y especie     1872
# Prefiero no responder         1250
# Name: count, dtype: int64

# %%
df['COLE_BILINGUE'].value_counts()
# Out:
# COLE_BILINGUE
# N    111897
# -     22621
# S      4777
# Name: count, dtype: int64

# %%
# Reemplazar valores de registros para el ahorro de recurso compuracional

# Crear un diccionario
replace_dict = {
                    '-' : 'No responde'
                }

# Implementar la función .replace
df['COLE_BILINGUE'].replace(replace_dict, inplace=True)
df['COLE_BILINGUE'].value_counts()
# Out:
# <ipython-input-63-52d87f27d96d>:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['COLE_BILINGUE'].replace(replace_dict, inplace=True)
# COLE_BILINGUE
# N              111897
# No responde     22621
# S                4777
# Name: count, dtype: int64

# %%
df['COLE_CARACTER'].value_counts()
# Out:
# COLE_CARACTER
# ACADÉMICO            77850
# TÉCNICO/ACADÉMICO    40783
# TÉCNICO              14604
# NO APLICA             1660
# -                     1362
# TÉCNICO/AC               1
# Name: count, dtype: int64

# %%
# Reemplazar valores de registros para el ahorro de recurso compuracional

# Crear un diccionario
replace_dict = {
                    '-' : 'NO RESPONDE'
                }

# Implementar la función .replace
df['COLE_CARACTER'].replace(replace_dict, inplace=True)
df['COLE_CARACTER'].value_counts()
# Out:
# <ipython-input-65-f50718f65e85>:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['COLE_CARACTER'].replace(replace_dict, inplace=True)
# COLE_CARACTER
# ACADÉMICO            77850
# TÉCNICO/ACADÉMICO    40783
# TÉCNICO              14604
# NO APLICA             1660
# NO RESPONDE           1362
# TÉCNICO/AC               1
# Name: count, dtype: int64

# %%
df['COLE_NATURALEZA'].value_counts()
# Out:
# COLE_NATURALEZA
# OFICIAL       91752
# NO OFICIAL    47543
# Name: count, dtype: int64

# %%
df['COLE_JORNADA'].value_counts()
# Out:
# COLE_JORNADA
# MAÑANA      62118
# COMPLETA    28117
# UNICA       14820
# TARDE       13893
# SABATINA    10881
# NOCHE        9465
# Name: count, dtype: int64

# %%
# Exportar el dataframe acumulado_saber_11 en formato CSV

df.to_csv('acumulado_saber_11.csv', index=False)
print(f"El archivo ha sido exportado exitosamente.")
# Out:
# El archivo ha sido exportado exitosamente.
